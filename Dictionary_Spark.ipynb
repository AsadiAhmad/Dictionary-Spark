# %% [markdown]
# # Step1: Install Librarys

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %% [markdown]
# # Step2: Import Librarys

# %%
import pyspark
from datasets import load_dataset
import pandas as pd
from collections import Counter
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, split, collect_list, concat_ws, udf
from pyspark.sql.types import StringType, ArrayType, MapType

# %% [markdown]
# # Step3: Download Dataset

# %%
dataset = load_dataset("persiannlp/parsinlu_translation_en_fa")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# # Step4: Preprocessing Dataset

# %%
train_data = dataset['train']
test_data = dataset['test']
validation_data = dataset['validation']

# %% [markdown]
# #Step5: Spark Config

# %%
spark = SparkSession.builder.appName("TranslationWordCount")\
                            .config("spark.driver.memory", "10g")\
                            .config("spark.driver.maxResultSize", "10g")\
                            .getOrCreate()

# %% [markdown]
# # Step6: Convert Dataset to Spark DF

# %%
def dataset_to_spark_df(dataset):
    data = []
    for item in dataset:
        source = item['source']
        target = item['targets'][0]
        data.append((source, target))
    return spark.createDataFrame(data, ["English", "Persian"])

# %%
df_train = dataset_to_spark_df(train_data)
df_test = dataset_to_spark_df(test_data)
df_validation = dataset_to_spark_df(validation_data)

# %% [markdown]
# # Step7: Merge Datasets

# %%
df_combined = df_train.union(df_test).union(df_validation)

# %% [markdown]
# # Step8: Split English Words

# %%
df_words = df_combined.withColumn("EnglishWord", explode(split(col("English"), " ")))
df_grouped = df_words.groupBy("EnglishWord").agg(collect_list("Persian").alias("Meanings"))
df_grouped = df_grouped.withColumn("Meanings", concat_ws(" ", col("Meanings")))

# %% [markdown]
# # Step9: Calculate top 10 Meaning words

# %%
def split_and_count(text):
    from collections import Counter
    words = text.split()
    counter = Counter(words)
    total_words = sum(counter.values())
    top_10_words = sorted(counter.items(), key=lambda item: item[1] / total_words, reverse=True)[:10]
    return dict(top_10_words)

split_and_count_udf = udf(split_and_count, MapType(StringType(), StringType()))

df_grouped = df_grouped.withColumn("TopMeaningCounts", split_and_count_udf(col("Meanings")))

# %% [markdown]
# # Step10: Show Result

# %%
pd.set_option('display.max_rows', None)

# %%
df_English_Dictionary = df_grouped.limit(100000).toPandas()

# %%
df_English_Dictionary[:1000]
# Out:
#                        EnglishWord  \
# 0                               !m
# 1                            "'Nor
# 2                         "'Seeing
# 3                          "(Come)
# 4                            "(One
# 5                          "(these
# 6                          "Aaron,
# 7                            "Alas
# 8                              "An
# 9                             "Art
# 10                            "Bad
# 11                        "Believe
# 12                        "Biased"
# 13                      "Certainly
# 14                          "Come,
# 15                           "Draw
# 16                          "Dunan
# 17                          "Every
# 18                           "Eyes
# 19                           "Far,
# 20                     "Foreigners
# 21                   "Grandfather"
# 22                           "Hear
# 23                            "Ill
# 24                           "Iron
# 25                        "Mention
# 26                      "Migration
# 27                       "Military
# 28                         "Naught
# 29                            "One
# 30                         "Saving
# 31                          "Short
# 32                    "Something's
# 33                           "Soon
# 34                         "Spirit
# 35                     "Statistics
# 36                         "Syrian
# 37                         "Throw,
# 38                           "Thus
# 39                            "Thy
# 40                           "True
# 41                          "True,
# 42                             "We
# 43                          "What!
# 44                           "When
# 45                            "Who
# 46                           "With
# 47                            "Woe
# 48                        "Worship
# 49                             "Ye
# 50                           "Yes,
# 51                            "Yet
# 52                        "YouTube
# 53                       "Zimbabwe
# 54                            "ah"
# 55                "anti-terrorism"
# 56                             "be
# 57                         "cheon"
# 58                          "chun"
# 59                           "come
# 60                          "coup"
# 61                      "cultural"
# 62                           "dean
# 63                  "demonstrating
# 64                        "desuyo"
# 65                        "draft"?
# 66                        "fella"?
# 67                         "filing
# 68                       "greatest
# 69                          "heart
# 70                           "hey"
# 71                  "hijabloggers"
# 72                    "humanisés".
# 73                           "i've
# 74                      "immediate
# 75                            "jin
# 76                          "latte
# 77                           "men"
# 78                         "myopic
# 79                    "non-violent
# 80                      "outline"?
# 81                     "partners"!
# 82                           "pine
# 83                         "public
# 84                    "questioning
# 85                       "reacheth
# 86                     "returned"?
# 87                      "sa-gong?"
# 88                          "soon"
# 89                         "them".
# 90                           "they
# 91                         "things
# 92                          "toy."
# 93                           "used
# 94                          "which
# 95                              #4
# 96                              #8
# 97                       #BREAKING
# 98                     #Euromaidan
# 99                     #InMySyria,
# 100                       #Obama's
# 101                          #PBN?
# 102                      #Roopbaan
# 103                       #Shahbag
# 104                  #UnNuevoRumbo
# 105                    #Zimbabwean
# 106                         #avoid
# 107                         #syria
# 108             #traspasodemandopy
# 109                        $1,375.
# 110                            $11
# 111                       $11,250.
# 112                        $12.95.
# 113                           $120
# 114                         $3,000
# 115                            $3.
# 116                           $3.2
# 117                             $4
# 118                         $4800,
# 119                      $500,000,
# 120                            $68
# 121                         $7200,
# 122                          $8.98
# 123                           &c.,
# 124                           &c.;
# 125                        ''ah''.
# 126                          ''big
# 127                       ''but''.
# 128                         ''fun.
# 129                      ''gladys.
# 130                     ''ha-ha,''
# 131                          ''i'm
# 132                       ''idney.
# 133                          ''see
# 134                  ''sweetheart,
# 135                        ''there
# 136                     ''uggos''.
# 137                      '300,000?
# 138                            '43
# 139                            '71
# 140                            '76
# 141                           '89!
# 142                         'AGAIN
# 143                    'Absolutely
# 144                       'Address
# 145                   'Aethelbert:
# 146                           'Ah!
# 147                          'Aha?
# 148                           'Ai!
# 149                        'Always
# 150                           'And
# 151                          'Anne
# 152                      'Antonio!
# 153                    'Anything's
# 154                  'Apparition,'
# 155                         'Avoid
# 156                        'Babley
# 157                          'Back
# 158                         'Bah!'
# 159                        'Battle
# 160                       'Beast'.
# 161                    'Beatrice,'
# 162                         'Beck?
# 163                           'Beg
# 164                      'Beggared
# 165                       'Between
# 166                         'Bless
# 167                           'Bob
# 168                     'Bonthrop'
# 169                         'Brian
# 170                         'But,'
# 171                     'Cambodian
# 172                   'Cancionero'
# 173                       'Charles
# 174                   'Clementine'
# 175                      'Colonel,
# 176               'Congratulations
# 177                      'Connor's
# 178                       'Consul'
# 179                       'Cookery
# 180                      'Cosette,
# 181                          'Dad,
# 182                           'Dan
# 183                      'Darling.
# 184                          'Dear
# 185                         'Death
# 186                        'Death!
# 187                          'Deed
# 188                     'Delighted
# 189                       'Despite
# 190                       'Diana,'
# 191                        'Divers
# 192                          'Does
# 193                          'Dona
# 194                     'Drownded?
# 195                       'Drunken
# 196                      'Ecstasy,
# 197                        'Ellen,
# 198                          'Emma
# 199                         'Emma?
# 200                     'English',
# 201                       'Exactly
# 202                    'Excellent!
# 203                         'Fifty
# 204                        'Finita
# 205                          'Folk
# 206                      'Forgiven
# 207                         'Forty
# 208                     'Francesca
# 209                      'Gandalf!
# 210                     'Generally
# 211                       'George!
# 212                      'Georgie,
# 213                   'Goldstein's
# 214                      'Goodness
# 215                         'Gosh!
# 216                       'Growed,
# 217                           'Gut
# 218                            'H.
# 219                           'HOW
# 220                       'Halloa,
# 221                    'Harrowdale
# 222                        'Harry!
# 223                      'Heineken
# 224                         'Hell,
# 225                         'Help!
# 226                   'Hirondelle'
# 227                          'Home
# 228                         'Houp,
# 229                       'Hurray!
# 230                        'Hurry!
# 231                            'I,
# 232                           'INK
# 233                  'Immediately.
# 234                  'Impedimenta!
# 235                 'Impertinence!
# 236                   'Impossible,
# 237                   'Interesting
# 238                         'Irish
# 239                          'Ivan
# 240                       'Jones?'
# 241                         'Jowyn
# 242                        'Judith
# 243                        'Julia,
# 244                          'July
# 245                        'Kemal,
# 246                          'Kiss
# 247                        'Known?
# 248                            'LA
# 249                         'Lads,
# 250                        'Lemon,
# 251                          'Life
# 252                            'M.
# 253                         'Mad.'
# 254                       'Madame,
# 255                     'Mamselle,
# 256                        'Market
# 257                       'Maxim!'
# 258                        'Maybe.
# 259                       'Meaning
# 260                          'Meet
# 261                         'Migh'
# 262                       'Mingle,
# 263                           'Mon
# 264                            'Mr
# 265                          'Mrs.
# 266                         'Nah,'
# 267                         'Nelly
# 268                       'Nobody'
# 269                            'OK
# 270                           'OK?
# 271                            'Og
# 272                            'Oh
# 273                          'Oh,'
# 274                           'Oi!
# 275                       'Olivia?
# 276                          'Only
# 277                         'Ouse.
# 278                     'Pafnute,'
# 279                     'Partners'
# 280                      'Peggotty
# 281                      'Perfect.
# 282                        'Permit
# 283                        'Phone.
# 284                        'Pieces
# 285                      'Pioneer'
# 286                       'Pippin!
# 287                         'Pooh!
# 288                   'Practically
# 289                  'Predictable'
# 290                      'Present!
# 291                       'Prince,
# 292                         'Queer
# 293                      'Recalled
# 294                      'Recently
# 295                    'Recollect!
# 296                          'Room
# 297                          'Rule
# 298                          'Run!
# 299                         'Sam!'
# 300                       'Say,who
# 301                        'Scarce
# 302                          'Sell
# 303                    'Separate!'
# 304                       'Severus
# 305                     'Shadowfax
# 306                        'Shame,
# 307                          'Shd.
# 308                         'Shit,
# 309                        'Should
# 310                          'Shut
# 311                  'Sixpenn'orth
# 312                          'Size
# 313                        'Sophie
# 314                       'Started
# 315                         'Sting
# 316                          'Stow
# 317                       'Strange
# 318                        'Supper
# 319                        'Sure.'
# 320                       'Sweet.'
# 321                   'Sweetheart,
# 322                    'Sweetmeats
# 323                        'Tain't
# 324                         'Take,
# 325                      'Telegram
# 326                           'Th'
# 327                          'Than
# 328                     'Thank'ee.
# 329                      'Thenard,
# 330                        'Tiptoe
# 331                        'Twould
# 332                          'Umm'
# 333                         'Ummm'
# 334                         'Union
# 335                            'Up
# 336                        'Wait,'
# 337                       'Warning
# 338                    'Well'well,
# 339                        'Whips,
# 340                      'Whoopdie
# 341                         'Whose
# 342                          'Why.
# 343                      'Witching
# 344                       'Witness
# 345                         'Woman
# 346                        'Yeh've
# 347                          'You.
# 348                         '_Wait
# 349                            'a'
# 350                           'alf
# 351                           'an'
# 352                            'as
# 353                  'attractions'
# 354                           'bad
# 355                    'beautiful'
# 356                        'before
# 357                      'boutsome
# 358                         'bunch
# 359                         'but'!
# 360                        'care'.
# 361                     'charity,'
# 362                   'comforter,'
# 363                        'course
# 364                        'cover'
# 365                         'daddy
# 366                          'damn
# 367                        'damn'?
# 368                         'dear,
# 369                      'departed
# 370               'disappointing'.
# 371                     'district'
# 372                         'eavy,
# 373                           'em,
# 374                         'emgot
# 375                            'er
# 376                         'ere's
# 377                           'flu
# 378                     'following
# 379                          'fore
# 380                     'frighten'
# 381                       'gastric
# 382                         'goat'
# 383                         'grown
# 384                            'he
# 385                        'head,'
# 386                         'holy'
# 387                          'ifs'
# 388                       'imself,
# 389                            'it
# 390                         'kings
# 391                    'leathers,'
# 392                       'letting
# 393                             'm
# 394                   'meandering'
# 395                          'much
# 396                        'murder
# 397                        'news,'
# 398                          'no'?
# 399                     'nonsense!
# 400                     'ordinary'
# 401                       'ostage.
# 402                           'out
# 403                   'partners'?-
# 404                      'police,'
# 405                     'precisely
# 406                      'privacy'
# 407                     'purified'
# 408                   'respectable
# 409                      'robber's
# 410                     'robbers';
# 411                             's
# 412                          'sam'
# 413                      'sceptic'
# 414                   'scientists'
# 415                            'se
# 416                    'secession.
# 417                     'senseless
# 418                        'settle
# 419                         'seven
# 420                         'she'.
# 421                        'sidey.
# 422                           'sit
# 423                       'smatter
# 424                          'some
# 425                         'sorry
# 426                    'specially.
# 427                   'stragglers.
# 428                       'strange
# 429                     'strategy.
# 430                  'supernatural
# 431                      'system';
# 432                       'system.
# 433                         'tea.'
# 434                         'thank
# 435                          'them
# 436                          'tis?
# 437                      'tongue.'
# 438                           'ull
# 439                 'unfortunately
# 440                       'usband,
# 441                      'useful,'
# 442                       'value,'
# 443                        'wanggo
# 444                       'waste'?
# 445                          'way,
# 446                      'welcome'
# 447                         'well,
# 448                         'what'
# 449                      'whether,
# 450                       'whiskey
# 451                           'why
# 452                       'women's
# 453                        'words'
# 454                        'you've
# 455                        'young'
# 456               (#HRTelections).
# 457            (#electionscroatia)
# 458                         (2008)
# 459                (@MJibranNasir)
# 460                   (@Maysaloon)
# 461                 (@MiriamJSdeA)
# 462                     (@MujMash)
# 463                (@RahmatullahN)
# 464                 (@Tita_Batres)
# 465              (@YousefMunayyer)
# 466                   (@alibomaye)
# 467              (@arindapradisty)
# 468                     (@besaqib)
# 469                 (@prashantrao)
# 470                   (@saraamroo)
# 471                     (@shafiur)
# 472                          (Able
# 473                     (Abundant)
# 474                         (After
# 475                         (Allah
# 476                          (Also
# 477                        (Before
# 478                          (CNA)
# 479                  (Companions),
# 480                      (Fasting)
# 481                        (Fire).
# 482                         (GIPA)
# 483                          (Good
# 484                   (Habitually)
# 485                          (High
# 486                            (I,
# 487                         (ISAF)
# 488                   (Israelites)
# 489                         (JPOA)
# 490                       (January
# 491                         (Just)
# 492                    (Messenger)
# 493                 (Prohibitions)
# 494                    (Prophet's)
# 495                 (Revelation),-
# 496               (Righteousness).
# 497                       (Sacred)
# 498                          (Sad)
# 499                   (Salvation),
# 500                       (Sinai):
# 501                         (Some)
# 502                       (Spain's
# 503                          (This
# 504                      (Thyself)
# 505                      (Truth)."
# 506                  (Unbelievers)
# 507                          (When
# 508                   (Yourselves)
# 509                         (after
# 510                          (all)
# 511                        (anew)?
# 512                      (answer).
# 513                       (aught),
# 514                      (behold),
# 515                         (best)
# 516                     (blissful)
# 517                         (body)
# 518                          (but)
# 519                        (case),
# 520                        (clean)
# 521                   (companions)
# 522                    (concealed)
# 523                    (consider):
# 524                         (deeds
# 525                         (deep)
# 526                     (destined)
# 527                          (e.g.
# 528                    (enjoyment)
# 529                     (enough)?"
# 530                         (even)
# 531                         (ever)
# 532                   (faithfully)
# 533                      (falsely)
# 534                      (favours)
# 535                       (feeling
# 536                        (foods)
# 537                    (forbidden)
# 538                      (formerly
# 539                           (fr)
# 540                         (frame
# 541                   (freshness):
# 542                     (furthest)
# 543                          (game
# 544                         (gift)
# 545                         (gods)
# 546                   (gradually),
# 547                     (helpless)
# 548                          (his)
# 549                          (how)
# 550                         (human
# 551                       (incur).
# 552              (intelligently)?"
# 553                    (intervene)
# 554                      (invented
# 555                          (jury
# 556                       (justice
# 557                          (kind
# 558                     (laughing)
# 559                     (lightly);
# 560                          (long
# 561                     (managing,
# 562                      (mankind)
# 563                       (merit):
# 564                        (mind):
# 565                           (nor
# 566                          (now)
# 567                         (now):
# 568                        (outer)
# 569                     (people),-
# 570                    (prohibited
# 571                    (property),
# 572                    (prosperity
# 573                         (rain)
# 574                         (rank)
# 575                   (repeatedly)
# 576                      (replete)
# 577                    (seductive)
# 578                      (shining)
# 579                       (signs):
# 580                       (slaves)
# 581                          (some
# 582                          (sort
# 583                        (still)
# 584                          (such
# 585                         (sure)
# 586                        (them),
# 587                        (them)?
# 588                  (therefore)."
# 589                      (things),
# 590                            (we
# 591                         (whoso
# 592                         (wide)
# 593                        (within
# 594                      (witness)
# 595                        (women)
# 596                      (wretch)!
# 597                          (your
# 598                   (yourselves)
# 599                             ,,
# 600                      ,Yemelian
# 601                     ,four,five
# 602                      ,intimate
# 603                          ,said
# 604                       ,staring
# 605                          ,when
# 606                             ."
# 607                            ...
# 608                           ...'
# 609                       ...3,000
# 610                         ...500
# 611                          ...Do
# 612                         ...I'm
# 613                      ...accept
# 614                     ...cooler.
# 615                        ...i've
# 616                         ...l'm
# 617                      ...recent
# 618                        ...take
# 619                       ...upset
# 620                    ...waiting.
# 621                        ...when
# 622                            .34
# 623                       .@safybh
# 624                          .But,
# 625                     .emphysema
# 626                           .hed
# 627                          .hey,
# 628                          .i'll
# 629                            .if
# 630                         .kills
# 631                            .or
# 632                         .sammy
# 633                     .something
# 634                        .stands
# 635                           .who
# 636                          /Mme.
# 637                       /Related
# 638                        /Venice
# 639                   /frozerama/?
# 640                           /ill
# 641                        /nuala/
# 642                        /please
# 643                       0-for-2,
# 644                          0.00.
# 645                            00%
# 646                            009
# 647                           0432
# 648                             07
# 649                      1,340,000
# 650                           1.30
# 651                     10/10/2004
# 652                       100,000.
# 653                            101
# 654                           101?
# 655                         107lbs
# 656                         10:45.
# 657                          10:51
# 658                           10th
# 659                             11
# 660                           111.
# 661                        112,000
# 662                          112th
# 663                           115.
# 664                          12.35
# 665                            124
# 666                            125
# 667                        125,000
# 668                           127.
# 669                     13/10/2012
# 670                            132
# 671                          1360.
# 672                       14-gauge
# 673                          14000
# 674                          1418.
# 675                           1425
# 676                           1435
# 677                           1492
# 678                           1496
# 679                            14?
# 680                          14th,
# 681                          14th.
# 682                             15
# 683                         15.000
# 684                           1500
# 685                            155
# 686                            15?
# 687                            15c
# 688                         15year
# 689                          1600,
# 690                          1695.
# 691                          16:29
# 692                       170,000,
# 693                           1706
# 694                          1708,
# 695                          1714,
# 696                          1742.
# 697                           175.
# 698                          1770,
# 699                          1783,
# 700                          1790,
# 701                           1791
# 702                           1793
# 703                           1808
# 704                          1809;
# 705                          1810,
# 706                          1814.
# 707                          1817.
# 708                          1827.
# 709                           1870
# 710                           1880
# 711                           1897
# 712                           1903
# 713                          1910,
# 714                          1911,
# 715                          1915.
# 716                          1921,
# 717                           1936
# 718                          1938.
# 719                          1946,
# 720                          1947.
# 721                           1953
# 722                           1957
# 723                           1958
# 724                          1958,
# 725                          1961,
# 726                          1962,
# 727                          1963,
# 728                          1966,
# 729                          1967,
# 730                          1968,
# 731                          1970s
# 732                           1987
# 733                          1996?
# 734                          19th?
# 735                         1:27am
# 736                             1;
# 737                             1L
# 738                      2,100,000
# 739                          2,428
# 740                            2.6
# 741                            20,
# 742                          20/80
# 743                            200
# 744                          2000s
# 745                         2008."
# 746                           2012
# 747                           2016
# 748                           2020
# 749                            205
# 750                           20cc
# 751                           2144
# 752                           2200
# 753                  23-years-old,
# 754                            232
# 755                            234
# 756                            23c
# 757                           23d,
# 758                           240.
# 759                         244877
# 760                         25.000
# 761                          25th,
# 762                            279
# 763                        287,425
# 764                           29.4
# 765                            296
# 766                           2:27
# 767                     3-year-old
# 768                            3.1
# 769                           30%:
# 770                            307
# 771                            30;
# 772                         30plus
# 773                           31/2
# 774                            317
# 775                            32,
# 776                        332ewd.
# 777                           33rd
# 778                      35yearold
# 779                            383
# 780                           3848
# 781                         390ibs
# 782                             3d
# 783                             3s
# 784                           3to1
# 785                          4,060
# 786                            4.2
# 787                        400,000
# 788                          4000,
# 789                            415
# 790                            428
# 791                           42a.
# 792                            442
# 793                            447
# 794                            451
# 795                           45s,
# 796                        465,000
# 797                            475
# 798                            495
# 799                        4:00...
# 800                           4:15
# 801                            4e.
# 802                           4op.
# 803                          5,000
# 804                           5.00
# 805                           5.45
# 806                       500/1000
# 807                       50pounds
# 808                             51
# 809                             54
# 810                         54,000
# 811                           55th
# 812                           57th
# 813                            591
# 814                           5:00
# 815                          5:00,
# 816                      5:00,when
# 817                           5:21
# 818                          5Char
# 819                        5minute
# 820                             6!
# 821                          60mm.
# 822                     610...987,
# 823                    614-hectare
# 824                           620.
# 825                            635
# 826                           650.
# 827                         66,000
# 828                            666
# 829                            69.
# 830                           69.3
# 831                        696,700
# 832                           6:15
# 833                             6a
# 834                             6r
# 835                           6th.
# 836                              7
# 837                           7.00
# 838                            700
# 839                           70mm
# 840                           70th
# 841                      70yearold
# 842                            711
# 843                            714
# 844                            718
# 845                           718.
# 846                         718...
# 847                           7256
# 848                            72p
# 849                            747
# 850                            75;
# 851                           75th
# 852                            78,
# 853                            800
# 854                          815".
# 855                           840M
# 856                            854
# 857                            86.
# 858                            862
# 859                           864.
# 860                            88%
# 861                           8:45
# 862                           9,80
# 863                        900,000
# 864                           9003
# 865                           91..
# 866                           911.
# 867                           939.
# 868                           95th
# 869                           96%,
# 870                           96.6
# 871                            975
# 872                            979
# 873                         99,99%
# 874                             9:
# 875                            :/.
# 876                         :Well,
# 877                          :Your
# 878                              ;
# 879                           ;An'
# 880                         ;Beats
# 881                         ;Fifty
# 882                       ;However
# 883                           ;Lay
# 884                    ;Meanwhile,
# 885                          ;One,
# 886                           ;Rot
# 887                          ;That
# 888                          ;When
# 889                         ;Which
# 890                         ;being
# 891                           ;ere
# 892                       ;looking
# 893                        ;marked
# 894                ;readjustment,;
# 895                        ;worthy
# 896                             <i
# 897                              =
# 898                     @Babakaram
# 899               @BalouchRightsAd
# 900                @ChrisBurkeShay
# 901                    @LastoAdri:
# 902              @MANSOOR_ALJAMRi:
# 903                       @PYCAPk.
# 904                  @Raafatology:
# 905                 @WilliamJHague
# 906                      @b_khlil:
# 907                @espiritusanto:
# 908                        @eyade:
# 909                  @jenanmoussa:
# 910                        @liliob
# 911                   @manimostofi
# 912  @periodistas21:@aprensamadrid
# 913                   @reem_tayeb:
# 914                 @selingiritBBC
# 915                           A.D.
# 916                        ACCOUNT
# 917                     ACCUSTOMED
# 918                   ACQUAINTANCE
# 919                        ADOPTED
# 920                         AEneas
# 921                           AGOS
# 922                          AIDS"
# 923                         AIIMS?
# 924                     ALIVEDNESS
# 925                         ALONE!
# 926                           ANNA
# 927                            API
# 928                         ARAFAT
# 929                          AREA!
# 930                     ARTHRITIS?
# 931                         ARTHUR
# 932                            ASH
# 933                         ATHOS.
# 934                      ATTACKING
# 935                           AWAY
# 936                         Aadel,
# 937                      Aardvark:
# 938                         Aaron)
# 939                          Abana
# 940                      Abbesses,
# 941                        Abbott?
# 942                   Abduallateef
# 943                       Abdullah
# 944                     Abdurahman
# 945                         Abel's
# 946                          Abib;
# 947                        Abijam,
# 948                       Abilene,
# 949                           Able
# 950                          Abner
# 951                         Aboard
# 952                       Abraham:
# 953                         Abram;
# 954                       Absalom:
# 955                          Abuja
# 956                    Academician
# 957                      Academies
# 958                         Accho,
# 959                       Accoules
# 960                      Account!"
# 961                      Aceldama,
# 962                           Ach!
# 963                     Achilles's
# 964                         Achish
# 965                       Ackerman
# 966                       Acquaint
# 967                          Acre,
# 968                           Act,
# 969                 Actuallythat's
# 970                      Adamastor
# 971                   Adderrahmane
# 972                  Additionally,
# 973                           Adel
# 974                         Adela.
# 975                    Adirondacks
# 976                       Adjutant
# 977                         Admah,
# 978                 Administrador?
# 979                 Adminstrador's
# 980                         Adnah,
# 981                       Adorable
# 982                      Adorable!
# 983                       Adoraim,
# 984                    Adrammelech
# 985                      Adultery!
# 986                    Adventurer,
# 987                       Advocate
# 988                       Aednat's
# 989                        Aednat,
# 990                         Afonka
# 991               African-American
# 992                    Afternearly
# 993                  Again,though,
# 994                         Agence
# 995                         Agents
# 996                          Ages,
# 997                        Aglaya.
# 998                        Aglaya;
# 999                        Agnes.'
#
#                                               Meanings  \
# 0    به او کمک کن تا بتواند از ما حمایت کند! پروردگ...
# 1    و به جای خدا چیزی را که سودی به تو نمی‌رساند و...
# 2    در حالی که شما را مرحله به مرحله [خاک، نطفه، ع...
# 3    قومش با او به گفتگوی بی منطق و ستیز برخاستند، ...
# 4    که از من و خاندان یعقوب ارث ببرد، و او را پرور...
# 5    [مشرکان] گفتند: [نه، قرآن سحر نیست] بلکه خواب ...
# 6                                     هارون، برادرم را
# 7    [همسر ابراهیم] گفت: ای وای بر من! آیا فرزند آو...
# 8                               "یک روز معمولی در کیف.
# 9    گفتند: شگفتا! آیا تو خود یوسفی؟! گفت: من یوسفم...
# 10   عادت روسها در سیگار کشیدن هیچ حد و مرزی نمی‌شن...
# 11   چون به آنان گویند: ایمان آورید چنان که دیگر مر...
# 12       اتهام الجزیره به پوشش «جانب دارانه» وقایع مصر
# 13   با سخت‌ترین سوگندهایشان به خدا سوگند خوردند که...
# 14   و نیز کسانی را که نفاق و دورویی ورزیدند، معلوم...
# 15   و عصایت را بیفکن. پس وقتی آن را دید که تند و س...
# 16          دونان گواندیان (Dunan Guandian) نوشته است:
# 17   بارنت روبین از متخصصین افغانستان در اولین نوشت...
# 18   به گفته کوباتانا در سایت جامعه باز سوروز بخشی ...
# 19   [از عقل ما] دور است و بسیار دور است آنچه به شم...
# 20   جمهوری چک: آیا خارجی‌ها بو می‌دهند ورونیکا می‌...
# 21   com مانا نیستانی هم در کارتونش با موضوع آلودگی...
# 22   برخی از کسانی که یهودی اند، حقایق [کتاب آسمانی...
# 23   گفتند: ما به تو و همراهانت فال بد زده‌ایم [و ش...
# 24   در حالی که بریتانیا به خبر درگذشت مارگارت تاچر...
# 25   و به یکی از آن دو نفر که دانست آزاد می‌شود، گف...
# 26   در این پژوهش مهاجرت به عنوان یک معیار انتخاب ش...
# 27   فرمان نظامی که برای حکم ابو رحمه استفاده شده ا...
# 28   و کافران گفتند: این [قرآن] چیزی نیست جز دروغی ...
# 29   عبدلرحمن ورسام که ساکن قطر است می‌نویسد رسانه‌...
# 30   جای سوال دارد که دستگیری چاپو درست دو روز پیش ...
# 31   آیا ندیدی کسانی را که [پیش از اعلام حکم جهاد] ...
# 32                 اما در کل "یک چیزی در جای خود نیست.
# 33   به کافران بگو: به زودی شکست می‌خورید و به سوی ...
# 34   اسناد سوریه که یک پروژه رسانه‌ای مربوط به جوان...
# 35   "بلاگ روسیه شون می‌نویسد آمار نشان می‌دهد که ن...
# 36   نام این اثر هنری نیز «سحری» نام دارد که حشام ک...
# 37   [به دو فرشته نگهبان و حافظ اعمال فرمان می‌دهند...
# 38   و این چنین پروردگارت تو را برمی گزیند و از تفس...
# 39   گفت: پروردگارا! برای من نشانه‌ای [جهت الهی بود...
# 40   و [نیز گفتند: در توضیح حقایق] جز به کسی که از ...
# 41   پیامبرانشان به آنان گفتند: یقینی است که ما بشر...
# 42   در یک سو، قتل او بسیاری از ترکها را شوکه و عصب...
# 43   اشراف و سران قومش که [از پذیرفتن حق] تکبر ورزی...
# 44   وحید نیکجو کاریکاتوری کشیده است که در آن احمد ...
# 45   زمانی که عیسی از آنان احساس کفر کرد، گفت: [برا...
# 46   بگو: دلیل و برهان رسا [که قابل رد، ایراد، شک و...
# 47   پس [در کنار جسد برادرش سرگردان بود که] خدا کلا...
# 48   و پیامبری از خودشان در میان آنان فرستادیم که خ...
# 49   و او کسی است که آسمان‌ها و زمین را در شش روز آ...
# 50   ساتنر افلیکیشن می‌گوید که دختران دبیرستانی جام...
# 51   در میان خودشان پنهانی و بسیار آهسته می‌گویند: ...
# 52   کریس بلاتمن می‌نویسد که یوتیوب مبدل به ارشیو ف...
# 53   زوت سیمز می‌گوید (انگلیسی) خیابان‌های پایتخت ز...
# 54                                        بچه، بگو آآآ
# 55   جلد پیشنویس قانون «ضد تروریسم» که توسط عفو بین...
# 56   «از جايگاه به حقت خورسند باش» مي دوني اين يعني...
# 57   زن دوم واژه هایش ترکیب شده از رودخانه hyeol سر...
# 58                                ببخشید؟ ... بهشت چون
# 59   برای مقابله با مسئلهٔ اختلاف نسل‌ها، یک کاربر ...
# 60   به دنبال این عکس‌العمل، سی‌ان‌ان، که تمام اتفا...
# 61   بلاگری به نام تمام چیزهای پاکستان می‌نویسد که ...
# 62              باید به اسم دین موریاتی ثبت شده باشه.‏
# 63   کمپین جهانی حقوق بشر در ایران ویدئوی کوتاهی با...
# 64             عجله کن میشه دسویو آروم باش میشه هایاکو
# 65                                  منظورت از طرح چيه؟
# 66                                              جوان ؟
# 67         من که اسمش رو نمي ذارم سيستم بايگاني پرونده
# 68   از آهنگ پاپ گنگنام استایل به عنوان «بزرگترین ص...
# 69   میرحسین موسوی یکی از رهبران اصلی جنبش سبز که د...
# 70                      چطور جرأت کردی به ایشون بگی هی
# 71   در ماه مارس ما از وجود گروه جدیدی از بلاگرها م...
# 72              Bravo pour les jihadistes «humanisés».
# 73      ميگه حدود 40 روز با ترس از ديگران ، زندگي كرده
# 74                   معني خانواده درجه اول رو مي فهمي؟
# 75   نام آن جین گویی یائو لویی است بله، آن کتابی از...
# 76   اگر در توییتر عبارت «هنر قهوه‌ی لاته» را جستجو...
# 77   برای نشان دادن همبستگی، حمایت و احترام من به «...
# 78   در سایت اینترنتی پی‌ام‌نیوز نیجریه (PM NEWS)، ...
# 79   آن زیپد مسئول سابق انجمن وکلای جوان در گرجستان...
# 80         کدام کلمه صحیح است "outline" یا "outlines"؟
# 81   و مشرکان از زراعت و چهارپایانی که خدا آفریده ب...
# 82                  برن بالای درخت کاج و کاج جمع کنند؟
# 83   بلاگ الساوادری تیم می‌نویسد که افرادی که در تظ...
# 84   هم اکنون کامبخش باید ۲۰ سال را در زندان مخوف «...
# 85   و مشرکان از زراعت و چهارپایانی که خدا آفریده ب...
# 86                           بازگشتي؟ قبلا اينجا بودي؟
# 87                                  سا-گونگ ؟ یعنی چی؟
# 88                  نجیب با واژه های ساده سر و رودخانه
# 89                       چه پچ پچي ؟ كي بود ؟ نمي دونم
# 90   ميبايست نوآموز باشند هنگامی که به آنان گویند: ...
# 91    اگه من بگم اوضاع بهتر میشه این یک حرف تکراری است
# 92   بیدو توصیف جامعه چینی‌ که زن را یک اسباب بازی ...
# 93   آیا می‌خواهید یک ماشین دست دوم بخرید، فقط ۴ یا...
# 94                     که دانش ما را پيرامون جهان هستي
# 95   شماره ۴: حساب کاربری جعلی توئیتر برای نخست وزی...
# 96      شماره ۸: مقایسه جرایم جنگی بوش، اوباما و پوتین
# 97   خبرفوری: اکنون تعداد کشته‌شدگان گازهای شیمیایی...
# 98   مرحله بعد برای جنبش یورومیدان چیست؟ تظاهرات خو...
# 99   @hadimadwar: #InMySyria, به خاطر این‌که دانش‌آ...
# 100  @NadiaE: خیلی خوب بود امروز صبح با خبر پیروزی ...
# 101  Http://www.fitclown.com/6-reason... #reasons #...
# 102  از انتشار روپبان، مجله دگرباشان بنگلادش و اینک...
# 103  این پست بخشی از پوشش ویژه اعتراضات شهبگ در بنگ...
# 104  بسیاری از مردم پاراگوئه از هشتگ #UnNuevoRumbo ...
# 105  فقط خدا می‌داند اگر امروز مورگان تسانگیری بود ...
# 106  Http://www.fitclown.com/6-reason... #reasons #...
# 107  Andy Carvin، استراتژیست NPR، از تریپولی، پایتخ...
# 108  بسیاری از مردم پاراگوئه از هشتگ #UnNuevoRumbo ...
# 109  و رقمی معادل هزار و سیصد و هفتاد و پنج دلار و ...
# 110  بله ، يازده دلار . فقط من 11 دلار براي هر ساعت...
# 111  خانه هنرمندانه برای دو خانواده، دیوار کو بها ه...
# 112  برام فقط 12.95 دلار خرج ميبره :که وقتي نخشون ر...
# 113  منو ببخشين . نميخوام عجله کنم ولي 120 ميليون د...
# 114  ری دوربینی به قیمت ۳۰۰۰ دلار خرید. روث حالا عش...
# 115  راکفلر زندگی کاری‌اش را با عنوان یک کارمند ساد...
# 116  و من مایلم این کار رو برای ‏3.2 میلیون دلار بک...
# 117  صبح زود روز یکشنبه خودمان را به بازار کهنه فرو...
# 118  و تازه ۴۸۰۰ دلار دیگر هم باری وسایل کمکی مورد ...
# 119  او مرا گول زد و پانصد هزار دلار مرا دزدید، حال...
# 120  از نظر ام اف کی، این فراورده شفا بخش که در هائ...
# 121  می‌بایستی به همراه انتقال اعتباری بمی زان۷۲۰۰ ...
# 122                         چقدر $8 . 98 . قشنگ نيست .
# 123  خانم فر فاکس فورا زنگ احضار را به صدا درآورد، ...
# 124  دوشیزه اسمیت ضمن پیچیدن نخ گاهی از من سؤال‌های...
# 125                                    بگو آآآآ- آآآآ-
# 126  احساس کردم يکي از اون لحظاته که بايد از اين اص...
# 127         منتظر يه اما و اگرم- خوب , بقيه هم مثل تو-
# 128                     باحال بودن رو برام توضيح ميدي؟
# 129                 ''گلاديس , گچيش كن باهاش حال نكن''
# 130                مقدار زيادي ها - ها ، بعدشم بو - بو
# 131  براي توصيفت فقط ميتونم بگم که دارم ناهار ميخور...
# 132           نه ، تو صفر امتياز به خاطر ! ايدني گرفتي
# 133  ميبينمت دي جي ، من قرار دارم بعدا مي بينمتون؟ ...
# 134  عزيزم! تو اخراج شدي، ولي چطوره قبل از اينکه بر...
# 135         يه مرد کج بود …که يه لبخند کج روي دهنش بود
# 136                                 قلبم ميگه اون زشته
# 137  و بعدش هم نگاهی تحقیر آمیز به او می‌انداختیم و...
# 138  تولد در سال ۱۸۴۳ و مفارقت روح از جسم در سال ۱۹۲۸،
# 139  او در انقلاب کمون ۱۸۷۱ دست داشته و به مرگ محکو...
# 140  ولی سال ۶۶ قهرمان باشگاهم ون بودم و دوباره سال...
# 141  من با معتقدات کشیش ساووایی و با اصول جاودانی ۸...
# 142  دوباره و دوباره، در هر حال، ما زبان عشق را می‌...
# 143                                            معرکه س
# 144  شعر ’‌خطاب به توتون‌، ‌ا را یادت است ‌که هاکین...
# 145  دست نویسی را برداشت به اسم آتل برت: یک تراژدی ...
# 146  اعرابی که در اطراف ما ایستاده بودند به رقص درآ...
# 147  ما چر فورا‌ نگاهش را به من دوخت و بعد به استیر...
# 148                      لگولاس شیون زنان گفت: آی! آی!
# 149  همراه سی دختر دیگر در یک شبانه‌روزی زندگی می‌ک...
# 150  او خنده‌کنان به من گفت: فقط می‌خواهم بدانم که ...
# 151  همین حالا داشتم قسمتی از آغاز آن گیر شتا ین را...
# 152             در را به داخل فشار دادم. سلام انتونیو.
# 153                : در طبیعت انسانی همه چیز ممکن است.
# 154  اگر موفقیت را از این غزل استیون سن که خیلی برت...
# 155             از نگاه کردن به چشم‌هایشان پرهیز کنید.
# 156  اسم او بابلی، آقای ریچاردز بابلی است. اسم واقع...
# 157  ایران: بازگشت به عصر حجر بانگ‬ زدند: برگردید ب...
# 158                                     یهودی گفت: به!
# 159                                    جنگ بیهوده است.
# 160  اما دلگیرم از اینکه برای ابراز محبتم نسبت به م...
# 161  راستی بئاتریس، می‌خواستم سؤالی بکنم، شما مردی ...
# 162                                              ؟ بک؟
# 163                      ببخشید قربان، چه فرمایشی بود؟
# 164                                دوست گدا و مطرود تو
# 165  و آخر از همه آراگورن به استقبال ائومر اهل رو ه...
# 166  آرتمس گفت: خدا خیرت بده! عمه‌ام که جا سنجاقی ر...
# 167  چون برای خواب از هم جدا شدیم، استیرفورث روی پل...
# 168  وقتی ارلاندو مرد را با نام دومش بانتروپ خطاب م...
# 169  فیونا ‌برایان به من گفت که امروز پیش آقای تامس...
# ...
# 720  {'آن': '1', 'نوشته': '1', 'تاریخ': '1', '۱۹۴۷'...
# 721  {'1953': '1', 'است': '1', 'مال': '1', 'اين': '...
# 722  {'شب': '1', 'قبل': '1', 'هفت': '1', 'و': '1', ...
# 723  {'پايگاه': '2', 'در': '7', 'اين': '2', 'سال': ...
# 724  {'چیزی': '1', 'من': '1', 'نزدیکای': '1', 'رو':...
# 725  {'مورد': '2', 'در': '5', 'دیپلماتیک': '2', 'تا...
# 726  {'او': '2', 'در': '3', '۱۹۶۲': '3', 'بود': '2'...
# 727  {'مورد': '2', 'در': '4', 'دیپلماتیک': '2', 'تا...
# 728  {'منتقل': '1', 'در': '2', 'گردید': '1', 'دنا':...
# 729  {'آزادی': '2', 'در': '3', 'بیان': '2', 'سال': ...
# 730  {'گروه': '1', 'در': '2', 'فرانسه،': '2', 'و': ...
# 731  {'شهرهای': '1', 'هنرمند': '1', 'بسیاری': '1', ...
# 732  {'1987': '3', 'در': '4', 'پر': '2', 'قصد': '1'...
# 733  {'فکر': '1', 'اون': '1', '1996': '2', 'چرا': '...
# 734  {'دهد': '2', 'را': '1', 'می': '1', 'تغییر': '1...
# 735  {'شک': '1', 'این': '1', 'رو': '1', 'تبدیل': '1...
# 736  {'صدای': '2', '۶،': '2', '۱۰،': '5', '۴،': '2'...
# 737  {'در': '1', 'قیمتی': '1', 'glenfiddich': '1', ...
# 738  {'هزار': '1', 'پوند': '1', 'و': '1', 'دو': '1'...
# 739  {'در': '2', 'روز': '1', 'پس': '1', 'زنده': '2'...
# 740  {'پهنا': '1', '1': '1', '2': '2', 'ارتفاع': '1...
# 741  {'در': '10', 'این': '4', 'و': '5', 'است': '4',...
# 742  {'رعایت': '1', 'مهم‌ترین': '1', 'تکنیک': '1', ...
# 743  {'در': '24', '200': '76', 'را': '22', 'و': '35...
# 744  {'چه': '1', 'من': '1', 'مشخصاتی': '1', 'جامعه‌...
# 745  {'سازمان': '1', 'دیگر': '1', 'ملل،': '1', 'نقل...
# 746  {'در': '30', 'را': '9', 'سال': '12', 'و': '14'...
# 747  {'۲۰۱۶': '4', 'چه': '3', 'در': '6', 'سال': '3'...
# 748  {'در': '3', 'سناریوی': '1', 'را': '1', 'ديدم':...
# 749                         {'205يارد': '1', '.': '1'}
# 750  {'نمکي': '1', 'بهش': '1', 'زورفان': '1', 'نيست...
# 751  {'کنه': '1', 'واحد': '1', 'ساختمان': '1', '214...
# 752  {'در': '1', 'چرا': '1', 'اونا': '1', 'هزار': '...
# 753  {'۲۳': '1', 'او': '1', 'روز': '1', 'ماهه': '1'...
# 754  {'جدي': '1', 'من': '1', 'نه': '1', 'روز': '1',...
# 755  {'ميتوني': '1', '234': '1', '...اتاق': '1', 'ر...
# 756  {'23': '1', 'ما': '1', 'cقربان': '1', 'داريم':...
# 757  {'شش': '1', 'فرانک': '1', 'مارس': '1', '…': '1...
# 758     {'‏220000': '1', '‏240.‏': '1', 'پوند.‏': '1'}
# 759                          {'244877': '1', '.': '1'}
# 760  {'موافقم': '1', '25000': '1', 'تا': '1', '.': ...
# 761  {'همه،': '1', 'در': '2', '۵': '1', 'مسلح': '1'...
# 762  {'279': '1', 'کد': '1', '6': '1', 'بخش': '1', ...
# 763  {'بودند،': '1', 'بین': '1', 'این': '1', '۲۸۷۴۲...
# 764  {'29/4': '1', 'شد': '1', 'كيلومتر': '1', '.': ...
# 765  {'فری': '1', '۲۹۶': '1', 'رسیده': '1', 'ایالت'...
# 766  {'نهر': '1', 'کف': '1', 'بعد': '1', 'ظهر': '1'...
# 767  {'اي': '1', '3': '1', 'قهوه': '1', 'پسر': '1',...
# 768  {'چه': '1', '1': '2', '3': '2', 'ميتونيد': '1'...
# 769  {'1': '1', 'خارج': '1', '8': '1', '30%': '1', ...
# 770  {'بريم': '1', 'سوم': '1', '307': '1', '،': '1'...
# 771  {'اصل': '1', 'در': '1', 'محل': '1', '۳۰؛': '1'...
# 772  {'سي': '1', 'شد': '1', 'ماده': '1', 'بشه': '1'...
# 773  {'فشار': '1', 'آب': '1', 'است': '1', 'بر': '1'...
# 774  {'‌نشستند،': '1', 'در': '2', '۳۱۷': '1', 'شمار...
# 775  {'حرفه‌ای،': '1', 'در': '2', '۲۶': '1', 'فرنسی...
# 776        {'بله،': '1', 'ماساچوست': '1', 'پلاک': '1'}
# 777  {'۳۳': '2', 'خود': '1', 'تماس': '1', 'اسوارانه...
# 778  {'معشوقه': '1', '35': '2', 'براي': '1', 'اگه':...
# 779  {'مشمول': '1', '۳۸۳': '1', 'جنایی': '1', 'این'...
# 780  {'3848': '1', 'نيويورک': '1', 'شرقي': '1', '.'...
# 781  {'و390پوند': '1', 'ترتيب': '1', '.': '1', 'به'...
# 782  {'در': '4', 'را': '4', 'این': '4', 'ژوئن': '4'...
# 783  {'عنکبوت': '1', 'نيويورک': '1', 'تور': '1', 'چ...
# 784  {'1': '1', '3': '1', 'ميدهم': '1', 'راه': '1',...
# 785  {'اسويلوپو': '1', 'مارکو': '2', 'اسویلوپو': '1...
# 786  {'میلیون': '2', '۲': '2', '2': '3', '4': '2', ...
# 787  {'در': '3', 'فشنگ': '3', 'هزار': '3', '۹': '3'...
# 788  {'چهار': '1', 'بگیر،': '1', 'را': '1', 'اکس': ...
# 789  {'تحقيقات': '1', 'بريم': '1', '71ام': '2', 'مر...
# 790               {'428': '1', '.': '1', 'شماره': '1'}
# 791  {'مراجعه': '1', 'کنيد': '1', 'گيت': '1', '42':...
# 792  {'دانش': '1', 'مذکر': '1', '422': '1', 'ريجکرس...
# 793  {'من': '1', 'چي': '1', 'داري': '1', 'را': '1',...
# 794  {'می‌کنن؟': '1', 'دفن': '1', 'کی': '1', 'آقای'...
# 795  {'بلند': '1', '۲': '1', 'لوله': '1', '۵۴،': '1...
# 796  {'465000': '2', 'من': '1', 'يکي': '2', 'اخاذي'...
# 797  {'در': '1', 'ما': '1', 'راهنمایی': '1', 'را': ...
# 798  {'نیوجرسی': '1', '۴۷۲': '1', 'لینکلن': '1', 'ت...
# 799  {'من': '1', '4؟ما': '1', '6': '1', 'باید': '2'...
# 800  {'در': '2', 'آن': '1', 'وی': '1', 'را': '1', '...
# 801  {'آقا': '1', 'من': '1', 'اوه،': '1', 'بله.': '...
# 802  {'او': '1', 'پنس': '1', 'اجاره‌ی': '1', 'این':...
# 803  {'در': '13', '5000': '16', 'هزار': '12', 'و': ...
# 804  {'حرکت': '1', 'اردوگاه': '1', '5': '1', 'ميکنه...
# 805  {'صبح': '1', '،': '1', '.': '1', '5:45': '1', ...
# 806  {'ای،': '1', 'روپیه': '1', 'های': '1', 'پس': '...
# 807  {'خوشم': '1', 'معمولیه': '1', '.': '2', 'اومد'...
# 808  {'در': '3', 'مثل': '2', 'و': '4', 'از': '3', '...
# 809  {'در': '5', 'این': '2', 'و': '6', 'حلقه': '2',...
# 810       {'بدهیم!': '1', 'ادامه': '1', 'بیایید': '1'}
# 811  {'۵۵': '1', 'در': '1', 'فلان': '1', 'بور': '1'...
# 812  {'57': '1', 'بين': '1', 'دنيا': '1', 'اونجا': ...
# 813  {'من': '2', 'اين': '2', 'تهمتي': '2', 'سال': '...
# 814  {'در': '6', '5': '11', 'از': '10', '،': '8', '...
# 815  {'پيش': '1', 'نشده': '1', 'چند': '1', 'همين': ...
# 816  {'بيدار': '1', '5': '1', 'شدي': '1', 'ديروز': ...
# 817  {'می‌گذشت': '1', 'ازمرز': '1', 'نه': '1', 'در'...
# 818  {'نظرات': '1', 'آن': '1', 'وبلاگ‌نویس': '1', '...
# 819  {'اي': '1', '15': '1', 'اينم': '1', 'يك': '1',...
# 820                                       {'6تا': '1'}
# 821  {'متری': '1', 'از۶۰': '1', 'خمپاه‌اند': '1', '...
# 822  {'377,': '1', '1,597.': '1', '233,': '1', '987...
# 823  {'پروژه': '1', 'مخالفان': '1', '۶۱۴': '1', 'هر...
# 824  {'مسا': '1', 'دارک': '1', 'هواپیمای': '1', 'بر...
# 825  {'تعداد': '3', 'بالغ': '2', '۶۳۵': '2', 'برخی'...
# 826  {'650': '1', '.در': '1', 'پايي': '1', 'ارتفاع'...
# 827  {'جنرالی:': '1', '66000': '2', 'جنرالي:': '1',...
# 828  {'این': '1', 'جمع': '1', 'و': '4', 'دو': '2', ...
# 829  {'اونیورسیته': '1', 'متقلب‌های': '1', 'در': '2...
# 830  {'میلیون': '1', 'بهره': '1', 'ایرانی': '1', 'د...
# 831  {'گزارشی': '1', 'وفق': '1', 'جامعه': '1', 'توس...
# 832  {'شش': '1', 'جف': '1', 'پانزده': '1', 'و': '3'...
# 833                 {'6آ': '1', 'راست': '1', '.': '2'}
# 834  {'گذارد': '1', 'قانونی': '1', '۶': '1', 'را': ...
# 835  {'منتقل': '1', 'در': '1', 'گردید': '1', 'دنا':...
# 836  {'در': '61', 'را': '42', '7': '99', 'و': '61',...
# 837  {'روز': '1', 'باشه': '1', 'هفتم': '1', '7': '3...
# 838  {'من': '6', 'شده': '5', 'را': '4', 'این': '6',...
# 839  {'متری': '2', 'در': '2', 'سینما': '3', 'پردة':...
# 840  {'سال': '1', 'برزیل:': '1', '۱۹۳۷': '1', 'کودت...
# 841  {'پيرمرد': '1', 'اونها': '1', 'و': '1', 'ببيني...
# 842  {'نوارها': '1', 'بازبيني': '1', 'را': '1', 'ما...
# 843  {'ما': '1', 'شده': '1', 'ظاهرا': '1', '714': '...
# 844  {'نيويورک،': '1', '718ورتوس': '1', 'مرکز': '1'...
# 845  {'مورد': '1', 'فکر': '1', 'خودت': '1', 'در': '...
# 846  {'ما': '1', 'داريم': '1', 'چيزه': '1', 'هواپيم...
# 847                            {'7256': '1', '.': '1'}
# 848  {'چيزي': '1', 'تسکين': '1', 'الکلي': '1', 'برا...
# 849  {'فرودگاه،': '1', 'محوطه': '1', 'فرانسه': '1',...
# 850  {'دوچرخه': '1', 'دلار': '1', 'هفت': '1', 'و': ...
# 851  {'پنجم،': '1', 'این': '1', 'هنگ': '1', 'و': '2...
# 852  {'۷۸': '1', 'غرب': '1', 'جاده': '1', 'می‌رفت':...
# 853  {'من': '5', 'در': '7', 'این': '5', 'را': '8', ...
# 854  {'گفت': '1', 'اون': '1', 'مه': '1', 'پرواز': '...
# 855  {'Nvidia': '2', 'بهتر': '1', 'برای': '1', 'کدا...
# 856  {'پرواز': '1', 'مسافران': '1', 'گوينده': '1', ...
# 857                                       {'۸۶.': '1'}
# 858  {'مسافرگيري': '1', 'در': '1', '862': '1', 'پرو...
# 859             {'تعداد': '1', 'بار': '1', '864': '1'}
# 860  {'بهترین': '1', 'در': '1', '٪۸۸': '1', 'کننده‌...
# 861  {'زنگ': '2', 'صدای': '1', 'هشت': '1', 'و': '2'...
# 862  {'نه': '1', 'ميانگين': '1', 'ولي': '1', 'نمرات...
# 863  {'فرانک': '2', 'آن': '3', 'هزار': '4', 'و': '2...
# 864  {'9003': '1', 'اين': '1', 'را': '1', 'رمز': '1...
# 865  {'حاضر.': '1', 'میر': '1', 'در': '2', 'و': '1'...
# 866  {'سپس': '1', 'روشن': '1', 'کردم': '1', '۹۱۱.':...
# 867  {'1939': '1', 'ببينم': '1', 'بذاريد': '1', '.'...
# 868  {'کنت،': '1', 'دشت': '1', 'پنجم،': '1', 'نود':...
# 869  {'تنظيم': '1', '96%': '1', 'شد': '1', '98%،': ...
# 870  {'شدن': '1', '%': '1', 'پوله': '1', 'حتي': '1'...
# 871  {'کردن': '1', 'گرمي': '1', 'زمينگير': '1', '97...
# 872  {'در': '1', 'اون': '1', 'پليس': '1', 'قتل': '1...
# 873  {'99': '3', 'در': '1', '99درصد': '1', 'آزادنه'...
# 874  {'۹:': '1', 'شمار': '1', 'اصل': '1', 'خود': '2...
# 875  {'دختر': '1', 'بالی': '2', 'خاطر': '1', 'گناه'...
# 876  {'گفت:': '1', 'شجاعانه': '1', 'ما': '1', 'خوب!...
# 877  {'گفت:': '1', 'اجل!': '1', 'حضرت': '1', 'می‌فر...
# 878  {'در': '522', 'این': '350', 'را': '575', 'بود'...
# 879  {'گفت': '1', 'مث': '1', 'مارتین': '1', 'یه': '...
# 880  {'گفت': '1', 'و': '1', 'از': '1', 'اختراع': '1...
# 881  {'در': '2', 'صلح،': '1', 'گونه': '1', 'و': '1'...
# 882  {'آگاهی': '1', 'نحوه': '1', 'باشد،': '1', 'این...
# 883  {'خداوند': '1', 'در': '1', 'خود': '1', 'بار': ...
# 884  {'در': '1', 'سخنرانی': '1', 'را': '1', 'اثنا':...
# 885  {'حمل‌کنندگان،': '1', 'آسمانه': '1', 'شمردند:'...
# 886  {'فرت': '1', 'لیلی': '1', 'معروف': '1', 'بی': ...
# 887  {'چقدر': '1', 'دارد': '1', 'بستگی': '1', 'این'...
# 888  {'چیزی': '3', 'دست': '6', 'را': '4', 'میدهند':...
# 889  {'بدبختی': '1', 'مسیحی،': '1', 'نظر': '1', 'بر...
# 890  {'چیزی': '1', 'ذهنی': '1', 'آن‌ها': '1', 'است'...
# 891  {'در': '1', 'مرا': '1', 'حالی': '1', 'داده': '...
# 892  {'دختر': '1', 'نازپرورده‌ها': '1', 'بودند،': '...
# 893  {'اتفاق': '1', 'خارج': '1', 'معمول': '1', 'بود...
# 894  {'اسکوییلر': '1', 'نشده': '1', 'میان': '1', 'ب...
# 895  {'قلعه': '1', 'بیگی‌اش': '1', 'آن': '1', 'نظر'...
# 896  {'در': '4', 'آن': '3', 'را': '6', 'و': '11', '...
# 897  {'تعداد': '6', 'ضربدر': '6', 'در': '6', 'چهار'...
# 898  {'مستقیما': '1', 'بعضی': '1', 'را': '1', 'قرار...
# 899  {'گروه': '1', 'کاربری': '1', 'حساب': '1', 'در'...
# 900  {'تقلید': '1', 'اندازه‌ی': '1', 'کافی': '1', '...
# 901  {'زباله‌دان': '1', 'بهترین': '1', 'در': '1', '...
# 902  {'خود': '1', 'در': '1', 'امیدواریم': '1', 'کنف...
# 903                                  {'@PYCAPK.': '1'}
# 904  {'آمریکا': '1', 'احمق': '1', '@Raafatology:': ...
# 905  {'من': '1', 'انگلیسی': '1', 'در': '1', 'پسر': ...
# 906  {'چه': '2', 'شدن': '1', 'زندانی': '1', 'این': ...
# 907  {'در': '1', 'موارد،': '1', '@espiritusanto:': ...
# 908  {'من': '1', 'همه': '1', 'نه': '2', '@eyade:': ...
# 909  {'بازگشت': '1', 'صبح': '2', 'در': '5', 'و': '3...
# 910  {'@liliob)': '1', 'Ochoa)': '1', 'در': '1', 'L...
# 911  {'سازمان': '1', 'بشری': '2', 'مستوفی،': '1', '...
# 912  {'چه': '1', 'بیشتری': '1', '@aprensamadrid': '...
# 913  {'بلند': '1', 'تعرض': '1', 'متهم': '1', 'ذات':...
# 914  {'خود': '1', 'همکاری': '1', 'بی': '2', 'رسانه‌...
# 915  {'دست': '1', 'در': '2', 'سال‌': '1', 'قسمت': '...
# 916  {'حساب': '4', 'در': '2', 'پول': '8', 'را': '3'...
# 917  {'من': '1', 'فکر': '1', 'نباید': '1', 'عادت': ...
# 918  {'بر': '1', 'می‌افزایم': '1', 'عدة': '1', 'دوس...
# 919  {'چه': '1', 'در': '1', 'بانو': '1', 'بیان': '1...
# 920  {'چنان': '1', 'بخواهید': '1', 'پارسایی': '1', ...
# 921  {'موج': '1', 'در': '2', 'جمعیت': '1', 'هزار': ...
# 922  {'احمق': '1', 'چونکه': '1', 'وی': '1', 'ای': '...
# 923  {'AIIMS': '1', 'در': '1', 'تشویق': '1', 'را': ...
# 924  {'ندارد': '1', 'سن': '1', 'ربطی': '1', 'سال': ...
# 925  {'بقیه': '1', 'ای': '1', 'پیمود': '1', 'آهسته‌...
# 926  {'کارنینا،': '1', 'آه،': '1', 'گفت:': '1', 'آن...
# 927  {'درگاه': '1', 'مشاغل': '1', 'دریافت': '1', 'ه...
# 928  {'وقوف': '1', 'عرفات:': '1', 'دوم:': '1', 'در'...
# 929  {'ندارین': '1', 'دروزازه‌بان': '1', 'حق': '1',...
# 930  {'مفاصل': '1', 'از': '1', 'ورم': '1', 'می‌برید...
# 931  {'احساس': '1', 'بال': '1', 'در': '2', 'حالی': ...
# 932  {'مرغوب‌ترین': '1', 'مسابقه‌ی': '1', 'دسته‌ای'...
# 933  {'من': '1', 'صمیم': '1', 'آغوش': '1', 'را': '1...
# 934  {'ما': '1', 'ما،': '1', 'را': '1', 'اثراتی': '...
# 935  {'کردن': '1', 'مرا': '1', 'ورداشتن': '1', 'خرم...
# 936  {'در': '2', 'موسیقی': '1', 'بازیگر': '1', 'دان...
# 937  {'مصر:': '1', 'بلاگرها': '1', 'چرا': '1', 'زند...
# 938  {'پروردگارا!': '1', 'ما': '2', 'گفتند:': '1', ...
# 939  {'نعمان': '1', 'پس': '1', 'ذریت': '1', 'و': '2...
# 940  {'در': '1', 'عالی،': '1', 'مدیره‌های': '1', 'ن...
# 941  {'گفت:': '1', 'ابوت': '2', 'دوشیزه': '1', 'جرو...
# 942  {'نهی': '1', 'معروف': '1', 'کمیته': '1', 'امر'...
# 943  {'در': '4', 'عبدالله': '9', 'الله': '5', 'را':...
# 944  {'می‌نویسد': '1', 'قربانی': '1', 'قطر': '1', '...
# 945  {'بودم': '1', 'ابل': '1', 'خسته': '1', 'را': '...
# 946  {'پیه': '1', 'مگذران': '1', 'مرا': '1', 'قربان...
# 947  {'رامه': '1', 'بعشا': '1', 'ترک': '1', 'این': ...
# 948  {'او': '1', 'همه': '1', 'می‌داد': '1', 'را': '...
# 949  {'ویندر،': '1', 'آ': '3', 'پولدار': '1', 'پسر'...
# 950  {'گفت:': '16', 'او': '16', 'در': '24', 'را': '...
# 951  {'کابینش': '1', 'اوقات': '1', 'خود': '1', 'در'...
# 952  {'او': '5', 'خدا': '6', 'خود': '5', 'آن': '7',...
# 953  {'گران': '1', 'می‌کرد،': '1', 'سلطنت': '2', 'آ...
# 954  {'آنکه': '1', 'گفت:': '3', 'سرداران': '2', 'زن...
# 955  {'در': '8', 'نیجریه': '2', 'هفته': '2', 'دیگر'...
# 956  {'آکادمی': '2', 'کلاسیک': '2', 'عضو': '2', 'آن...
# 957  {'نه': '2', 'در': '4', 'باید': '2', 'این': '3'...
# 958  {'من': '1', 'حضور': '1', 'نیز': '1', 'را': '1'...
# 959  {'عدلیه': '2', 'راهی': '2', 'عمارت': '2', 'ناق...
# 960  {'ما': '2', 'گفتند:': '1', 'مسخره]': '1', 'روز...
# 961  {'او': '1', 'ناگاه': '1', 'هیکل': '2', 'لنگ': ...
# 962  {'عجب!': '1', 'سونیا': '1', 'زد:': '1', 'ای': ...
# 963  {'مانند': '1', 'در': '1', 'آن': '1', 'نقش‌ها':...
# 964  {'گفت:': '8', 'من': '6', 'در': '9', 'شاول': '7...
# 965  {'آکرمن': '3', 'است.': '2', 'شده': '2', 'این':...
# 966  {'داشته،': '1', 'اقدام': '1', 'او': '2', 'وطری...
# 967  {'در': '1', 'عرضی': '1', 'چهارم،': '1', 'قسمت'...
# 968  {'کمیسیون': '1', 'این': '1', 'را': '2', 'خودش'...
# 969  {'است': '1', 'در': '1', 'راز': '1', 'واقع': '1...
# 970  {'می‌گوید:': '1', 'ظاهر': '1', 'گردد': '1', 'و...
# 971  {'سیساکو،': '1', 'کلاه‌ها': '1', 'عبدالرحمن': ...
# 972  {'دیدارهای': '1', 'فرهنگی،': '1', 'این': '1', ...
# 973  {'در': '3', 'متحد': '2', 'و': '5', 'الحمد': '2...
# 974  {'بعید': '1', 'آدلا': '1', 'مادموازل': '1', 'د...
# 975  {'منطقه': '3', 'در': '4', 'قتل': '2', 'را': '3...
# 976  {'آجودان': '2', 'را': '3', 'آجودانی': '2', 'و'...
# 977  {'عموره': '2', 'سدوم': '2', 'سمت': '2', 'صبوئی...
# 978  {'فکر': '1', 'مردان': '1', 'دادن': '1', 'نجات'...
# 979  {'گفت:': '1', 'باسیلیو': '1', 'سینی': '1', 'تن...
# 980  {'هزار': '1', 'و': '1', 'بيرون': '1', 'لشکر': ...
# 981  {'کردن': '1', 'صحبت': '1', 'گودی': '1', 'و': '...
# 982  {'گفت:': '1', 'حیرت': '1', 'پرستیدنی!': '1', '...
# 983  {'مصربه': '1', 'درسال': '1', 'سلطنت': '1', 'و'...
# 984  {'گفت:': '2', 'خدای': '1', 'بریهوه،': '1', 'من...
# 985                                      {'زنا!': '1'}
# 986  {'من': '1', 'کشتی': '2', 'پذیرفتم': '1', 'و': ...
# 987  {'در': '14', 'را': '13', 'و': '18', 'ادووکیت':...
# 988  {'نفس': '2', 'می‌گوید:': '1', 'آیدین': '1', 'آ...
# 989  {'ره.': '1', 'آ': '1', 'می‌گوید:': '1', 'تورین...
# 990  {'گفت:': '1', 'شمرده': '1', 'مؤکد': '1', 'اوزر...
# 991  {'آنلاین': '1', 'پس': '1', 'نظر': '1', 'از': '...
# 992  {'آن': '2', 'پس': '1', 'سال': '1', 'و': '4', '...
# 993  {'در': '1', 'شدن': '1', 'پس': '1', 'و': '1', '...
# 994  {'تیرانی': '2', 'مویک': '1', 'در': '4', 'گذشته...
# 995  {'تعداد': '1', 'او': '1', 'زیادی': '1', 'دلال‌...
# 996  {'وسطی،': '6', 'در': '18', 'را': '3', 'و': '16...
# 997  {'گفت:': '12', 'در': '10', 'این': '9', 'را': '...
# 998  {'من': '2', 'خود': '2', 'این': '2', 'را': '3',...
# 999  {'آشنا': '1', 'همواره': '1', 'هرکس': '1', 'و':...

# %% [markdown]
# # Step11: Calulate Persian Dictionary

# %%
df_words2 = df_combined.withColumn("PersianWord", explode(split(col("Persian"), " ")))
df_grouped2 = df_words2.groupBy("PersianWord").agg(collect_list("English").alias("Meanings"))
df_grouped2 = df_grouped2.withColumn("Meanings", concat_ws(" ", col("Meanings")))

def split_and_count(text):
    from collections import Counter
    words = text.split()
    counter = Counter(words)
    total_words = sum(counter.values())
    top_10_words = sorted(counter.items(), key=lambda item: item[1] / total_words, reverse=True)[:10]
    return dict(top_10_words)

split_and_count_udf = udf(split_and_count, MapType(StringType(), StringType()))

df_grouped2 = df_grouped2.withColumn("TopMeaningCounts", split_and_count_udf(col("Meanings")))

# %%
df_Persian_Dictionary = df_grouped2.limit(100000).toPandas()

# %%
df_Persian_Dictionary[:1000]
# Out:
#                 PersianWord  \
# 0                  !!!يالا!
# 1                   !!البته
# 2                     !!خون
# 3                        !،
# 4                    !آزمون
# 5                     !آنرا
# 6                      !آیا
# 7                !اعلیحضرت!
# 8                   !افسر!؟
# 9                     !الا.
# 10                !اميدوارم
# 11                     !اه،
# 12                   !اونها
# 13                   !اونهم
# 14                     !اگر
# 15                   !اگرچه
# 16                      !ای
# 17                !اینجاست!
# 18                    !بابا
# 19                    !باشه
# 20                   !بانو!
# 21                   !بانوي
# 22                    !بدون
# 23                     !برو
# 24                     !بري
# 25                   !بريم!
# 26                    !برید
# 27                  !بعلاوه
# 28                   !بمونم
# 29                     !بهت
# 30                    !بياي
# 31                 !بيخيال-
# 32                 !بگیریدش
# 33                     !بیا
# 34                    !بیا!
# 35                  !تاکسي،
# 36                     !تو،
# 37                 !جاناتان
# 38                     !جين
# 39                    !حالا
# 40                    !حشره
# 41                   !دخترا
# 42                   !دستات
# 43                   !دقيقا
# 44                    !رئیس
# 45                  !راستشو
# 46                    !رودي
# 47                    !رييس
# 48                     !زود
# 49                    !زود!
# 50                   !زيادي
# 51                     !سال
# 52                   !سرده،
# 53                    !سعيد
# 54                      !شش
# 55                    !شكست
# 56                   !عزیزم
# 57                     !عمل
# 58                     !فتي
# 59                      !فر
# 60                   !فرار؟
# 61                    !فورا
# 62           !فوراعاليجنابو
# 63                     !قتل
# 64                   !لعنتي
# 65                  !لوبيا!
# 66                  !مامان.
# 67                   !مایکل
# 68                   !مشاور
# 69                   !معنيش
# 70                  !مقاومت
# 71                  !ممنونم
# 72                 !ممنونم!
# 73                  !ميدونم
# 74                     !مگه
# 75                 !میخواهم
# 76                  !ندارد،
# 77                !نمیخواهی
# 78                      !هم
# 79                  !همشونو
# 80                    !همین
# 81                   !هو-چن
# 82                      !يه
# 83                    !پدر‎
# 84                      !پس
# 85                   !پس...
# 86                     !پسر
# 87                    !چطور
# 88                   !چندلر
# 89                      !چي
# 90                   !چگونه
# 91                   !چیکار
# 92                     !کات
# 93                    !کشور
# 94                    !کمکم
# 95                      !کي
# 96                     !کِی
# 97                    !گفتي
# 98                      !یا
# 99                 !یانگوم!
# 100                     !یه
# 101             "outlines"؟
# 102                     "y"
# 103                   "آها!
# 104                  "ارباب
# 105                    "اما
# 106                  "امید،
# 107                  "اینک،
# 108                   "برای
# 109                   "برخی
# 110                "بروید!"
# 111                 "برگشته
# 112                 "بستایی
# 113                "بوسه‌ای
# 114                    "حتی
# 115             "دعوت‌شدگان
# 116                     "دو
# 117                  "روانه
# 118                 "روزهای
# 119               "زنامکن."
# 120                  "علاوه
# 121                    "فکر
# 122                 "قندی")
# 123                  "موتور
# 124                 "ناظران
# 125                  "نیازی
# 126                  "نیشکر
# 127                    "همه
# 128                     "پس
# 129                    "پیش
# 130                    "کسب
# 131       #EgyPresElection،
# 132            #EgyPresElex
# 133             #InMySyria,
# 134                   #PBN?
# 135           #UnNuevoRumbo
# 136                  #avoid
# 137      #traspasodemandopy
# 138                #آمریکا،
# 139               #اسیدپاشی
# 140                 #زندانی
# 141                   #سوئد
# 142                  #مدارس
# 143                     %17
# 144            ''تاسكالوسكا
# 145                   ''قلب
# 146                 'گذاشتن
# 147     (#electionscroatia)
# 148         (@LuisBareiro)،
# 149              (@M_Bizar)
# 150          (@MiriamJSdeA)
# 151      (@O_s_a_m_e_h_h_p)
# 152          (@Tita_Batres)
# 153             (@shurufu)،
# 154                   (Asma
# 155                (B.Com(H
# 156                  (Bejan
# 157                  (Broad
# 158                   (CNA)
# 159                  (Erdem
# 160                  (Harim
# 161                (Huseyin
# 162                   (Jose
# 163                   (NSA)
# 164                   (NTV)
# 165                   (Sina
# 166            (Trafficking
# 167                (syrup).
# 168                  (ازنو)
# 169            (اسپانیایی)»
# 170               (انگلیسی)
# 171             (اپلیکیشنی)
# 172                    (این
# 173               (بپرسند)،
# 174                   (جائی
# 175                   (حماس
# 176                   (خراج
# 177                  (دومین
# 178                   (زانگ
# 179                   (شهر)
# 180                    (صلی
# 181                  (ظهور)
# 182                   (عدد)
# 183                  (عیسی)
# 184                  (غربا)
# 185               (فلش‌موب)
# 186                  (مباحث
# 187                  (معادل
# 188                    (نام
# 189                 (وخواهی
# 190            (کاتالیزور)»
# 191                  (کارتس
# 192                (کشورهای
# 193                   (گروه
# 194                    (گفت
# 195                (＠深圳E行動)
# 196                  )فریاد
# 197                   )یهوه
# 198                     +‌،
# 199                      ,,
# 200                   ,,,بي
# 201                  ,,,نفع
# 202                  ,امکان
# 203                   ,اونو
# 204                   ,اووم
# 205                    ,اين
# 206                ,بالاخره
# 207                 ,برخورد
# 208                 ,سرورم.
# 209                 ,لباساي
# 210                    ,مگه
# 211                     ,هي
# 212                    ,هيچ
# 213                 ,يانگزو
# 214                   -آقاي
# 215                 -آويخته
# 216                     -او
# 217                   -اوه,
# 218                    -اين
# 219                    -تو!
# 220                    -تو,
# 221                     -تي
# 222                     -خب
# 223                  -زماني
# 224                  -مختلف
# 225                    -مرد
# 226                 -ميدونم
# 227                     -نه
# 228                    -ولي
# 229                      -‏
# 230                     ...
# 231                .....اول
# 232               ....اينجا
# 233             ....اينجوري
# 234               ....بخاطر
# 235                ....خوب,
# 236                ....خودت
# 237                ....شگفت
# 238                 ....قول
# 239             ....نميخواي
# 240                  ....هر
# 241               ....هفتاد
# 242              ...آخ...آخ
# 243                  ...آره
# 244                 ...آروم
# 245          ...آشپزخانه...
# 246                  ...آه،
# 247                ...اثبات
# 248                ...احساس
# 249                 ...ازَت
# 250                ...افتاد
# 251               ...البته،
# 252               ...اهميتي
# 253                   ...او
# 254                 ...اول،
# 255                ...اولا،
# 256                  ...اوم
# 257              ...اونجاها
# 258                   ...اي
# 259                 ...ایون
# 260               ...باشید،
# 261                ...بانوي
# 262                 ...بايد
# 263               ...ببینمش
# 264                ...بروید
# 265                ...بوهاي
# 266                  ...بگو
# 267             ...تاثيراتي
# 268                 ...تباه
# 269               ...تبديلش
# 270               ...تجربه،
# 271                ...تشخیص
# 272                 ...تصور
# 273                 ...تمام
# 274                 ...جایی
# 275                ...حداقل
# 276                 ...حرفه
# 277                 ...حقیر
# 278               ...خائنان
# 279               ...خدايا،
# 280                ...خطایش
# 281                ...خواهم
# 282                 ...خيلي
# 283                ...دارند
# 284                ...داشتم
# 285               ...داشتيم
# 286                ...دختري
# 287                 ...دراز
# 288          ...درخواستهایی
# 289                ...دریای
# 290               ...دزمودس
# 291                ...دلیلی
# 292              ...دوباره،
# 293                 ...دیدم
# 294                 ...رئیس
# 295                 ...راست
# 296                 ...روزي
# 297                  ...روي
# 298                 ...زمان
# 299            ...زودباش...
# 300                 ...زیبا
# 301                 ...زیرا
# 302              ...سربازها
# 303             ...سرورم...
# 304               ...سلسله،
# 305                  ...شام
# 306                 ...شروع
# 307                ...طوفان
# 308               ...طولانی
# 309                ...عاليه
# 310                ...عزيزم
# 311                  ...عكس
# 312                 ...عيبي
# 313                  ...قرص
# 314                  ...قصد
# 315                ...مادرم
# 316               ...ماشيني
# 317                ...مبتلا
# 318            ...متأسفم...
# 319              ...متاسفم،
# 320                 ...مثله
# 321               ...مجازات
# 322                ...مراتب
# 323                ...مراسم
# 324              ...مريضمون
# 325                ...معنیش
# 326                 ...ملکه
# 327                  ...من؟
# 328                 ...منشی
# 329                ...منطقا
# 330                  ...منم
# 331                ...مورد،
# 332      ...ميدوني...مطمئنم
# 333               ...میتونی
# 334              ...میخواهی
# 335                 ...میشه
# 336                ...نظامی
# 337                ...نوشته
# 338                ...نيازه
# 339                 ...نيست
# 340                 ...نگاه
# 341                ...واقعا
# 342               ...پرستار
# 343                  ...پس،
# 344                ...پنهان
# 345              ...پیشرفتی
# 346                 ...چرخه
# 347                ...چونکه
# 348                  ...چي؟
# 349                  ...چی؟
# 350              ...چیزهایی
# 351                ...کالين
# 352               ...کريسمس
# 353                  ...کسی
# 354                 ...کمرم
# 355                  ...گاو
# 356                 ...گفتن
# 357                   ...گل
# 358                  ...یاد
# 359                 ...یُوه
# 360                  ..براش
# 361                   ..توي
# 362                  ..دكتر
# 363                  .8نفري
# 364                    .EMZ
# 365                      .،
# 366                  .اجازه
# 367                .استفاده
# 368                 .افرادي
# 369                   .الگو
# 370                    .اما
# 371                  .او-يي
# 372                .اونوقت،
# 373                   .اوه،
# 374                   .اينو
# 375                    .اگر
# 376                 .ببخشيد
# 377                   .بذار
# 378             .برومیتوانی
# 379                    .بله
# 380                  .بنشين
# 381                    .بيا
# 382                   .بيست
# 383                 .بگذارش
# 384                  .تامين
# 385                    .تو؟
# 386                   .جايي
# 387                  .جمعيت
# 388                .جنازَتو
# 389                 .جورچين
# 390                  .جيکوب
# 391                  .حالا،
# 392                   .حرکت
# 393                   .خانم
# 394                    .خوب
# 395                  .خودتو
# 396                  .خيالت
# 397                   .خیله
# 398                    .دست
# 399                  .دقيقا
# 400                   .دليل
# 401                 .دوستَت
# 402                   .دکتر
# 403                     .را
# 404                    .رخت
# 405                .رودخانه
# 406                    .روز
# 407                   .زياد
# 408                .سالهاست
# 409                     .شب
# 410                   .ضايع
# 411                  .عجیبه
# 412                   .فرار
# 413                   .فردا
# 414                 .فهميدي
# 415                    .فکر
# 416                .كالاهاي
# 417                   .لطفا
# 418              .متأسفانه،
# 419               .مسئوليتش
# 420                  .مشاور
# 421                 .مطمئنم
# 422                    .منم
# 423                   .نایب
# 424                   .نمرت
# 425                    .نمك
# 426                  .هي!هي
# 427                    .هيچ
# 428                   .وارد
# 429                .واقعيتش
# 430                  .وايسا
# 431                  .وِلِش
# 432                     .يا
# 433                   .يالا
# 434                    .يکي
# 435                  .چارلي
# 436                   .چيزي
# 437                    .کار
# 438                   .کشتی
# 439                   /تایپ
# 440                    0415
# 441                      07
# 442               10/000سال
# 443              10/10/2004
# 444                100000يك
# 445                 1000سکه
# 446                 100دلار
# 447                   100ها
# 448                     101
# 449                      11
# 450                   11000
# 451                  110000
# 452                    1111
# 453                   11845
# 454                 123پوند
# 455                     124
# 456                     125
# 457                   13سال
# 458                   14000
# 459                    1435
# 460                    1496
# 461                  14ساعت
# 462                      15
# 463                 15...16
# 464                    1500
# 465                  150000
# 466                     155
# 467                 15ساله،
# 468                    1620
# 469                   16:29
# 470                    1870
# 471                    1880
# 472                    1897
# 473                    1903
# 474                    1936
# 475                    1943
# 476                    1953
# 477                    1957
# 478                    1958
# 479                    1987
# 480                  1989رو
# 481                   1درصد
# 482                     200
# 483                  20000$
# 484                2000مايل
# 485                    2012
# 486                    2016
# 487                    2088
# 488                 20دلاري
# 489                    2144
# 490                    2199
# 491                   22ماه
# 492             23....42...
# 493                     232
# 494                     234
# 495                  244877
# 496                 24سالشه
# 497                  25.000
# 498                     272
# 499                     279
# 500                      29
# 501                    2:27
# 502                  2دلاري
# 503                   2ساعت
# 504                   2کيلو
# 505                 3000سکه
# 506                 300دلار
# 507                 300پوند
# 508                     307
# 509                    30تا
# 510                 3100سال
# 511                     334
# 512                 350کيلو
# 513                     351
# 514                    3848
# 515                    3:25
# 516                     3ام
# 517                   3تايي
# 518                  3ثانيه
# 519              3کيلومتربا
# 520                     415
# 521                    41آ،
# 522                     422
# 523                     428
# 524                     447
# 525                 45دقيقه
# 526                  498سال
# 527             4Rendezvous
# 528                    4؟ما
# 529                5000پوند
# 530                      51
# 531                      54
# 532                     581
# 533                   587ها
# 534                     591
# 535                    5:00
# 536                    6/96
# 537                 600دلار
# 538                     625
# 539                     647
# 540                   66000
# 541                      69
# 542                    6:15
# 543                    6:23
# 544                    6®76
# 545                 6بیلیون
# 546                     6تا
# 547                  6درايو
# 548                       7
# 549                     700
# 550                 700دلار
# 551                  70ساله
# 552                     714
# 553                     718
# 554                718ديديم
# 555                 7240168
# 556                    7256
# 557                  7ثانيه
# 558                  7سالشه
# 559                     800
# 560                     854
# 561                     862
# 562                     870
# 563                    8:45
# 564                 8آدام16
# 565                   8ساله
# 566                     8شب
# 567                    9003
# 568                     975
# 569                      9:
# 570                    9:25
# 571                   :::يا
# 572                  :اجازه
# 573                    :اما
# 574                    :اون
# 575                  :اونها
# 576                   :بزار
# 577                   :بصير
# 578                   :بلدم
# 579                     :به
# 580                   :تنها
# 581               :جنگجويان
# 582                  :داراي
# 583          :درميان‌گذاشتن
# 584                   :ديدي
# 585                    :رنگ
# 586                   :زيرک
# 587                   :صداي
# 588                   :عزيز
# 589                    :غير
# 590                    :مال
# 591           :متاسفم,اولين
# 592                  :متهور
# 593                    :محل
# 594                   :مردم
# 595                    :هيس
# 596                     :چپ
# 597                       ;
# 598                       =
# 599                  =آشفته
# 600                    =دفن
# 601                    =زشت
# 602                    =نه،
# 603                  ?...به
# 604                   ?اينا
# 605                     ?تو
# 606                ?سپاهمون
# 607                   ?قسمت
# 608               ?مسلماشما
# 609                    ?چرا
# 610                   ?چطور
# 611              @Babakaram
# 612             @LastoAdri:
# 613       @MANSOOR_ALJAMRi:
# 614           @Raafatology:
# 615                @RafifJ:
# 616                  @Rawya
# 617         @espiritusanto:
# 618                 @eyade:
# 619           @jenanmoussa:
# 620            @noorbahman:
# 621            @reem_tayeb:
# 622                 @۳amrB:
# 623                    ALBA
# 624                      AM
# 625                     API
# 626                      AZ
# 627                Ackerman
# 628             Adventures)
# 629                 Agência
# 630                   Aroon
# 631                 Attacks
# 632                Attitude
# 633                  B166eR
# 634                    BODS
# 635                   Baily
# 636               Bangalore
# 637                    Bank
# 638                Battery)
# 639                 Beeping
# 640                  Beings
# 641                     BlL
# 642               Bostnescu
# 643               Bountiful
# 644                  BriIIo
# 645               Budapest.
# 646                     But
# 647                      By
# 648                     C24
# 649                    CHSL
# 650                Cartes's
# 651               Celebrate
# 652                    Ceux
# 653                    Chen
# 654                    Ciro
# 655                  Cirque
# 656                Cockburn
# 657              Cocksucker
# 658              Compelling
# 659                     DC8
# 660                     DID
# 661                   Delta
# 662                 Demotix
# 663                 Devil's
# 664                     Did
# 665                   Drugs
# 666                   EAPC،
# 667                     ELI
# 668                     EOD
# 669               Education
# 670                     Eee
# 671                   Eneko
# 672                Espósito
# 673                 Farshid
# 674                   Ferry
# 675                   Final
# 676                    Fisk
# 677                   Fleet
# 678                    FtM:
# 679                     GDP
# 680               Grizzlies
# 681                     Gta
# 682                    H1-B
# 683                 Hadzic)
# 684              Hala/Cleo،
# 685                 Harding
# 686                   Hidoe
# 687                    High
# 688                 Homonym
# 689                     I'm
# 690                      If
# 691                   Imgur
# 692                     Inn
# 693              Innovating
# 694           International
# 695                Introdio
# 696                   Iran)
# 697                     JAM
# 698                   Jaime
# 699                   Jones
# 700                    July
# 701                       K
# 702                  Kerala
# 703                   Kyoto
# 704                     LEN
# 705                Lakpriya
# 706                      Le
# 707                     MDL
# 708                    MNLA
# 709                     MPP
# 710                 Maharaj
# 711             Malalaquak»
# 712                 Manipal
# 713                  Manish
# 714                 Martin,
# 715                Matout۷،
# 716                Mohammed
# 717                Monalisa
# 718                  Monroe
# 719                  Motown
# 720              Mrityunjay
# 721                   Mundo
# 722                 M۴۵Paul
# 723                    NOVA
# 724                   NYT's
# 725                 Nabais,
# 726                National
# 727                 Nemesis
# 728                   Nobel
# 729                      O.
# 730                Observer
# 731                     Oct
# 732                     One
# 733                    Oohh
# 734                   Oppo،
# 735                   Osame
# 736                     PDF
# 737                      PI
# 738                 PIRELLI
# 739                      PM
# 740                     PSU
# 741                      Pa
# 742              Patagonian
# 743                   Paulo
# 744                Petition
# 745                Pimentel
# 746               PlatePlay
# 747                    Play
# 748               População
# 749                 Portnoy
# 750             Pottermore:
# 751                    Pاون
# 752                   Rageh
# 753                 RainTPL
# 754                 Razones
# 755                    Real
# 756                    Red)
# 757                  Romeu.
# 758         Ruiz-Gallardón)
# 759                     Rus
# 760                  Russia
# 761                SAbaseen
# 762                 SICamp)
# 763                      SL
# 764           Salinasanchez
# 765                     Sao
# 766                 Science
# 767                     Sep
# 768                   Shaam
# 769                  Shiraz
# 770                    Sign
# 771                Situação
# 772                    SlSM
# 773                 Snootch
# 774                     So?
# 775                  Source
# 776                Squidito
# 777                   Steve
# 778                 Syria's
# 779                     TED
# 780                     TPP
# 781                   Then?
# 782               Thousands
# 783                Tomorrow
# 784                  Trying
# 785                   Tutti
# 786                Twitter.
# 787                   Tyler
# 788                     UN,
# 789                 Uh-huh!
# 790                Unilever
# 791                 Updated
# 792                Valdosta
# 793                  Valium
# 794                   Voice
# 795                   WIMPs
# 796                     Wat
# 797                 WebView
# 798                  Whoops
# 799                 Women`s
# 800              WordRidden
# 801                   World
# 802                  Zoinks
# 803                 [*ترجمه
# 804                    [آب]
# 805                   [آرام
# 806                   [آیا]
# 807                  [آیات]
# 808               [اراده‌اش
# 809                  [ارجاع
# 810                 [ازدواج
# 811                [ازدواج]
# 812                  [اقرار
# 813                 [انبوهی
# 814               [انسان‌ها
# 815                     [او
# 816                  [اوقات
# 817                  [ایمان
# 818                [بارانی]
# 819                   [باطل
# 820                     [بت
# 821                   [برخی
# 822                  [برخی]
# 823           [برپادارندگان
# 824                  [بزرگی
# 825               [بنابراین
# 826                   [بنگر
# 827                 [بگویی:
# 828                    [تا]
# 829                   [تحقق
# 830                [تنگناها
# 831                  [جاری]
# 832              [جامعه‌های
# 833                 [جنیان]
# 834                   [جهان
# 835                 [حفاظت]
# 836                    [حفظ
# 837                 [حکومت،
# 838                   [خانه
# 839                    [خشم
# 840                 [داستان
# 841                 [درستی]
# 842                [درقیامت
# 843                 [درهای]
# 844                  [ذاتا]
# 845               [رسانیدن]
# 846                 [رسولان
# 847                 [رعایت]
# 848                  [رهایی
# 849                   [ستیز
# 850                   [سرای
# 851                 [سرزمین
# 852                 [سفرهای
# 853                 [سلیمان
# 854                    [شرک
# 855                   [شریک
# 856                   [شوخی
# 857              [شیطان‌ها]
# 858                   [صدای
# 859                   [ظاهر
# 860                  [عذاب]
# 861               [عذاب‌ها]
# 862                 [عمیقا]
# 863                  [قرآن]
# 864                  [قیامت
# 865                    [مات
# 866                 [مانند]
# 867                  [مایه]
# 868                  [محتوی
# 869                [محرومیت
# 870                   [محمد
# 871                [مخالفان
# 872                 [مخالفت
# 873                  [مشمول
# 874                 [مطیعان
# 875                 [معرفت،
# 876                  [معین]
# 877                  [ملازم
# 878                 [مناسب]
# 879                   [مهلت
# 880                  [مکان]
# 881                  [مکتب]
# 882                   [نفوس
# 883                 [نهایتا
# 884                 [نوشته]
# 885                 [هدایت]
# 886                   [هلاک
# 887                [همانان]
# 888                 [همانند
# 889                    [همه
# 890                  [همگی]
# 891                    [وآن
# 892                  [وآنان
# 893                 [واجبات
# 894                 [وامشان
# 895                  [وسایل
# 896                   [وقت]
# 897                   [وقتی
# 898                 [ومحکمی
# 899               [پاداششان
# 900                [پاکدامن
# 901           [پروردگارتان]
# 902                    [پست
# 903                   [پوچ]
# 904                 [پیامبر
# 905                [پیراسته
# 906                   [پیش]
# 907                   [چرا]
# 908                  [چیزی]
# 909                  [کاری]
# 910                [کافران،
# 911                   [کالا
# 912                    [کام
# 913                [کریمان]
# 914                [کفرورزی
# 915                  [کوتاه
# 916                  [کیفر]
# 917                  [گویی]
# 918                      [ی
# 919                   [یاری
# 920                  [یعنی:
# 921                   [یهود
# 922             [یکتاپرستی]
# 923  \dfrac{x}{x^2+a^2}\,dx
# 924               _0327.bmp
# 925               _1183.bmp
# 926               _1308.bmp
# 927               _1485.bmp
# 928                   _جونگ
# 929                becoming
# 930                    bien
# 931                      cc
# 932                   cheon
# 933           co/aX۲o۵V۲D۵R
# 934           co/flnyN۴۶mu۰
# 935                commons.
# 936                   could
# 937                     cpj
# 938                   delhi
# 939                     did
# 940                      en
# 941                   erdem
# 942                    even
# 943                    film
# 944                   fleet
# 945                     got
# 946              hardingush
# 947                 helping
# 948                     him
# 949                    hope
# 950                  https:
# 951                  hungry
# 952                   hyeol
# 953                    iPad
# 954        johannesfactotum
# 955                    lent
# 956                    lies
# 957               luckyno۳.
# 958                     map
# 959                   mind?
# 960                   moshi
# 961                  mwausk
# 962                      ne
# 963                    neet
# 964                    net)
# 965                 net/jrf
# 966                   nocte
# 967                    nova
# 968                  origen
# 969                    own.
# 970          periodistas۲۱:
# 971                   pride
# 972                 promise
# 973                  rhythm
# 974                  right.
# 975                    six.
# 976                    some
# 977                 somehow
# 978                   still
# 979                    suja
# 980                     tub
# 981                     two
# 982                tباربارا
# 983                      us
# 984             victor-MUFC
# 985                  violet
# 986                   wide!
# 987                   wrote
# 988                    you.
# 989                 {‌بزم‌،
# 990                       ~
# 991                    «Day
# 992                    «The
# 993                   «hate
# 994              «literacy»
# 995                 «sexual
# 996                      «،
# 997                     «آب
# 998                   «آبل»
# 999                   «آقای
#
#                                               Meanings  \
# 0               come on! do it, do it, do it! come on!
# 1                                  of course you will!
# 2                                              blood!!
# 3    red army! attack the white army's square in we...
# 4               exam ground for physician ladies only!
# 5    i'll get the medicines to make his bathing wat...
# 6    aren't those astragalus sprouts?! did you... f...
# 7    your majesty! your majesty! your majesty! my l...
# 8        official?! yeah, right! it's an obvious trap!
# 9                                          ella. ella!
# 10                        i hope she throws up on you.
# 11   ugh, walter! oh, my eyes! oh, tommie! oh, tomm...
# 12   they're all gone! all the physicians and physi...
# 13     this year that we're even making the offerings!
# 14   you'll be kicked out if you keep working this ...
# 15                                     even so, no way
# 16      you wretch! you witch! you wretch! you wretch!
# 17             here! here! it's here! it's coming out!
# 18                    - say it! - i'm your bitch. dad!
# 19   ok, ok, i'll tell you! i wasn't going to say t...
# 20                                       madam! madam!
# 21   miss! miss! miss! miss! i beg you! my lady! my...
# 22   you have no clue?! then she's acting that way ...
# 23   get out! get out! get out! get out! huh? get t...
# 24                                         spit. what?
# 25                                 let's go! let's go!
# 26   get in! move over! move over! move! go in! pul...
# 27   besides we have to hurry to catch the boat! be...
# 28                                         stay. stay.
# 29   i told you not to go there! i told you, i'm no...
# 30       come on. you gotta get back in the game here.
# 31                                 - really? - please!
# 32   catch him! tie him up! drag her away and punis...
# 33   let's go what?! you want to be spanked, don't ...
# 34                                     come on! hurry!
# 35                                         taxi. taxi!
# 36              come here, you! i will kill you today!
# 37                                           jonathan!
# 38                                                jin!
# 39   you can go back now! now! now you find out! on...
# 40             her name's celia. she's not a bug lady.
# 41                                    girls, sit down!
# 42                            put your arms around me.
# 43                                         absolutely!
# 44                                        chief! boss!
# 45                                 tell me the truth?!
# 46                                          rowdy, no!
# 47           chief! find the ironware workshop leader!
# 48   got it?! what are you doing? bring it right no...
# 49                                   quickly! quickly!
# 50                                 'cause he's loaded.
# 51         i don't know. you dumped her on new year's.
# 52                           it's cold, so get inside!
# 53                                sayid! sayid! sayid!
# 54     six guys couldn't do anything about two women?!
# 55                                          we failed!
# 56                                              honey!
# 57   surgical, medical, surgical, yeah! surgical, m...
# 58   i'm arranging to have food delivered. fatty ha...
# 59                                     the oven is on!
# 60                                             elope?!
# 61   take care of it quickly! give the key back to ...
# 62    send his highness to the palace immediately! no!
# 63                           please stop the massacre!
# 64   dammit! dammit! damn! crap. damn! you bastard!...
# 65                                         bean! bean!
# 66                                           mom. mom!
# 67                                       it's michael.
# 68                           consul jang! yon. consul!
# 69   leaving buyeo to establish a new nation, means...
# 70                                come on! stand back!
# 71             thank you! thank you, madam! thank you!
# 72                               thank you! thank you!
# 73   i'm a skank. she never says no to anyone, so.....
# 74   how dare you do such things not knowing that t...
# 75   i'm going to send you to a place with two tigers!
# 76   the queen has nothing to do with this she can'...
# 77         aren't you going to get water?! why you...!
# 78   you said they could shoot the spot without you...
# 79                       kill them all! kill them all!
# 80   do it now! you'll disobey the king's command? ...
# 81                                           hao chen!
# 82   you should bring it in some day. look at the t...
# 83                                             father!
# 84   then the meat must've tasted flat! report when...
# 85       then... just why is it turning out this way?!
# 86   my own son, so why are you stopping me?! dude!...
# 87   stay away! how dare you approach me! how dare ...
# 88   chandler, nobody likes breaking up with someon...
# 89   - what's it gonna take? - your cupcake. what's...
# 90                  how dare you lie to us like this?!
# 91   what are you doing?! drag her out right now! w...
# 92                                     - cut! and cut!
# 93   and i wanted to do something great as the chef...
# 94                   help me run away! please! please!
# 95                                            not you.
# 96                                   when did i yell?!
# 97                                    you said it! no!
# 98   or do you have something against me?! or the s...
# 99   jang-geum! jang-geum! jang-geum! jang-geum! ja...
# 100                                   there's trouble!
# 101  Which word is the correct one "outlines" or "o...
# 102            What animals begin with the letter "y"?
# 103                                               'Ah!
# 104                  'Well, Master Samwise,' she said.
# 105  But sending out the orders is not an easy task...
# 106                        "Hope, the last thing dies"
# 107                  'Behold the King Elessar is come!
# 108  And Rebekah heard when Isaac spake to Esau his...
# 109  "Some were musicians, one was an actor, and a ...
# 110  Therefore all things whatsoever ye would that ...
# 111  And thou saidst unto thy servants, Except your...
# 112                   'Praise them with great praise!'
# 113  Yes, indeed, she said automatically and, press...
# 114  Nafiseh writes that she posted her own photo w...
# 115  So Jesus had compassion on them, and touched t...
# 116  Syria: "Two Years Later, We are All So Terribl...
# 117  And when we had accomplished those days, we de...
# 118  At this first pride parade, participants with ...
# 119  And when the tempter came to him, he said, If ...
# 120  She added, “Besides, the kind of manteau that ...
# 121  'Think you that Wormtongue had poison only for...
# 122  What is your review of Mahatma Gandhi And His ...
# 123                     "My daily challenge is riding.
# 124  Harinjaka, besides his work at Fanamby, is als...
# 125  “We don’t need to submit each of our photos fo...
# 126  To highlight the range of ways in which videos...
# 127  Meanwhile, Russian reporters say "all is well"...
# 128  'Then you must go. 'Then come, and let your br...
# 129  “Before putting online our private videos, we ...
# 130  And Joseph said unto his brethren, and unto hi...
# 131  Interest on Twitter, under the hashtags #EgyPr...
# 132  Interest on Twitter, under the hashtags #EgyPr...
# 133  @hadimadwar: #InMySyria, you enter medical sch...
# 134  Http://www.fitclown.com/6-reason... #reasons #...
# 135  Many Paraguayans used hashtags #UnNuevoRumbo (...
# 136  Http://www.fitclown.com/6-reason... #reasons #...
# 137  Many Paraguayans used hashtags #UnNuevoRumbo (...
# 138  Stop lying @CNN pic.twitter.com/y9AamNfKXF The...
# 139  Iran's leading conservative newspaper, Kayhan,...
# 140  If they had taken two Mullahs instead of five ...
# 141  Swedish Foreign Minister, Carl Blidt, won't go...
# 142  A school was destroyed in Gilan under heavy snow.
# 143                                data upload , 17% .
# 144                           ''my tuscaloosa heart''?
# 145                              ''tuscaloosa heart''.
# 146                                     apostrophize .
# 147  No matter how divided we are in these or futur...
# 148      Journalist Luis Bareiro (@LuisBareiro) wrote:
# 149  If we do not have pity for ourselves, what we ...
# 150  Carlos Garcia (@carlosgarciareq) and Mirian de...
# 151  It does not matter if it's Hassan or Hussein ,...
# 152  Also, Martha Evelyn Batres (@Tita_Batres) uplo...
# 153  GV's Sub-Saharan Africa authors - Omar Mohamad...
# 154  Asma Shirazi, an anchorperson for a leading TV...
# 155  When should I start studying for first semeste...
# 156      Poet Bejan Matur said on her Twitter account:
# 157  The mountain climbers sent a call for help on ...
# 158  In an attempt to show the increasing popular s...
# 159  The Duran Adam (Standing Man) protests started...
# 160  Harim Peiris at Groundviews raised the questio...
# 161  Huseyin Avni Mutlu, the governor of Istanbul, ...
# 162  If approved by the Senate and signed by Presid...
# 163  Image created by Small Media and used with per...
# 164  The protests against media censorship continue...
# 165  In July 2013, singer Wu Hongfei was detained a...
# 166  Iran is also not currently a party to the 2000...
# 167  Everyone loves Canada, eh? And no one can give...
# 168  He shall not make himself unclean for his fath...
# 169  Along with their collective blog, their work a...
# 170  However in this update, he says that the strik...
# 171  Today, possibly got filtered that symbolized d...
# 172  Under the hashtag #NoEsUnaColaEsUnCamino (it i...
# 173  And all things are of God, who hath reconciled...
# 174  The mangroves where it occurred are located ab...
# 175  The conflict that's been going on for the past...
# 176  Tremble, ye women that are at ease; be trouble...
# 177  Why do the Gulf States ($123B arms purchases f...
# 178  Joel Martinsen from DANWEI translated an inter...
# 179  Then Pashur smote Jeremiah the prophet, and pu...
# 180  And if ye are in doubt as to what We have reve...
# 181  So he came near where I stood: and when he cam...
# 182  Now when Daniel knew that the writing was sign...
# 183  Why didn't (don't) followers of the Hebrew Bib...
# 184  The changeable suits of apparel, and the mantl...
# 185  The innovative approach to marriage proposals ...
# 186  Rather, they elected him to play the role of m...
# 187  Ghazala's ex-husband Jehangir Khan was awarded...
# 188  In the meantime, street art, which communicate...
# 189  Tremble, ye women that are at ease; be trouble...
# 190  His input into a panel entitled “Technology as...
# 191  It is common for colorado presidents (Cartes i...
# 192  Long-term solutions are quite difficult. They ...
# 193  There is no Diif btw Taliban & Mqm (Altaf grou...
# 194  And the people answered and said, God forbid t...
# 195  Shenzhen has come up with an idea to wipe out ...
# 196  Behold, the eye of the LORD is upon them that ...
# 197  My God will cast them away, because they did n...
# 198  He turned his head and blinked at the men who ...
# 199  - give it back! - "exterior: hoth. this is the...
# 200                                     that wretch...
# 201                                     more profit...
# 202                               that's not possible.
# 203  think about who will benefit buyeo more and ch...
# 204                                    i think it's...
# 205                               fine. let's do that.
# 206                thank goodness, it's the mod squad.
# 207  good bedside manner, good rapport with the nur...
# 208                        i can't leave your majesty.
# 209  our soldiers' arms are made of iron castings t...
# 210  that's bad, right? you want the number to be l...
# 211           an assassin had slipped into the palace,
# 212            do not neglect anything in preparation.
# 213        chief, sul pyong's group has left yangzhou.
# 214      - if i can say one thing... - mr. maek dosoo!
# 215                                           beetle .
# 216  where is she? i don't know. please don't kill me.
# 217                 - oh, am i kimmy? - no, i'm kimmy.
# 218  - that's... - it's true that silla army came, ...
# 219                                 they escaped. you!
# 220                                     you! back off.
# 221  mrs blitt over there needs the tips procedure,...
# 222  the store'll be open tomorrow. more coffee. yo...
# 223  - it can be your fantasy. - when i achieve it,...
# 224  ... haven't yet been released, dropped 26 stor...
# 225                                pig man! yes, good!
# 226              i know. i can't believe you did this!
# 227  - why us? - not as much hae, - no. - no? - wer...
# 228  - you can't consider it a reoccurrence. - he's...
# 229  yeah, i don't know, george. all the instrument...
# 230  if cunning people let on about it... tell me.....
# 231    how can you put tofu in first?! radish first...
# 232  there is something so there's someone... someo...
# 233            - ends. - how does a date with you end?
# 234  if you're so stupid as to confront the chief o...
# 235         - well, his father... - i hate his father.
# 236  - who cares? it's only a grade. - really? what...
# 237            rewrap a dirty bandage. it's phenomenal
# 238  this island is bad. you don't bring sun back. ...
# 239                      you, uh, you ready to tell me
# 240  do anything... we must get it no matter what! ...
# 241  could i have a price check on a 74-year-old fe...
# 242                                        ow... ow...
# 243  yeah... - yeah, well... - we shaved the baby. ...
# 244                   slow down... turn around slowly.
# 245                        the kitchen... right now...
# 246  oh, no... oh, that... what do you call it... o...
# 247      it would be hard to prove it was misdiagnosis
# 248  if you're doing this because you feel sorry to...
# 249                              i need you to tell me
# 250  that's not so, sir! this happened because the ...
# 251  of course, rice wine and salt...! i forgot the...
# 252         which is why i don't mind dr cox paging me
# 253  makes decisions after much thought sir oh will...
# 254  ok, let's get started first, prepare the chick...
# 255  first, no matter what the reason you should ex...
# 256                                              um...
# 257                        over there... over there...
# 258               you idiot... incompetent dumb-ass.''
# 259                eun-sung and yoon-kyun can learn...
# 260  but if you had checked carefully, you may have...
# 261  miss... miss! please, i beg you... don't be li...
# 262  people who are taking care of the patients sho...
# 263                        let me see it... let me see
# 264  go on... ok. you're right. let's do that... go...
# 265  i can't remember a time i smelled such a delic...
# 266     say... just say it. say, ''elliot, stay in bed
# 267    and how that affects your personal lives and...
# 268                     so far would be ruined then...
# 269                      and started delivering babies
# 270       experience is something she can build and...
# 271  physician lady yeul-yee's diagnosis and wrong ...
# 272  it helps if you visualise running toward somet...
# 273  that's all we just have to prepare... recite i...
# 274  you missed the public health center where you ...
# 275  please prevent that at least you should've bro...
# 276   the important thing is that we're professionals,
# 277  feeble thing? how could someone who has saved ...
# 278  to pick out the faithful, the traitors and vil...
# 279        god, if something had of happened to her...
# 280  sure. physician lady jang-geum has finally rea...
# 281  i'll get permission for you to go out of the p...
# 282  all right, clara. to your sister being a... we...
# 283      she has a chronic illness and this disease...
# 284  i heard about the decision i was practicing......
# 285  we were watching tv, then he pooped in monica'...
# 286  that's when you find out that that pretty girl...
# 287              did you call for a nurse? lie down...
# 288  i'm sorry to tell you this but they're appeals...
# 289   this is a gift from the far sea it's rare and...
# 290                              desmodus rotundus and
# ...
# 720  {'the': '6', 'War"': '1', 'director': '1', 'of...
# 721  {'the': '2', 'that': '2', 'Mundo,': '1', 'BBC'...
# 722  {'the': '2', 'pull': '1', 'that': '1', '(‏@M45...
# 723  {'play': '1', 'high': '1', '3': '1', 'like': '...
# 724  {'the': '2', 'NYT's': '1', 'Huma': '1', 'in': ...
# 725  {'(03/07/2009)': '1', 'copyright': '1', 'Demot...
# 726  {'Flickr': '1', '2014': '1', 'by': '1', 'taken...
# 727  {'the': '1', 'in': '1', 'want': '1', 'nemesis'...
# 728  {'Malala': '1', '12': '1', 'Celebrate': '1', '...
# 729  {'The': '1', 'a': '1', 'capital': '1', 'flouri...
# 730  {'quoted': '1', 'the': '2', 'a': '1', 'Here': ...
# 731  {'Steps': '1', 'Oct': '1', 'Arabia:': '1', 'Sa...
# 732  {'over': '1', 'red': '3', 'one': '1', 'this': ...
# 733                            {'oohh': '1', '.': '1'}
# 734  {'most': '1', 'the': '1', 'reliable': '1', 'sm...
# 735        {'َUser': '1', 'wrote:': '1', 'Asame': '1'}
# 736  {'a': '1', 'can': '1', 'How': '1', 'file': '1'...
# 737  {'valid': '1', 'a': '1', 'of': '1', 'for': '1'...
# 738  {'pirelli': '2', 'miraculous': '1', 'elixir': ...
# 739  {'the': '5', 'with': '3', 'and': '2', 'for': '...
# 740  {'which': '1', 'the': '1', 'government': '1', ...
# 741  {'the': '2', 'Pa': '1', 'tweeted': '1', 'low':...
# 742  {'the': '4', 'average': '1', 'how': '1', 'temp...
# 743  {'Beijing': '1', 'journalist': '1', 'Juste': '...
# 744  {'Malala': '1', '12': '1', 'Celebrate': '1', '...
# 745  {'Vírus': '1', 'the': '3', 'a': '1', 'wrote': ...
# 746  {'available': '1', 'Is': '1', 'in': '1', 'Barc...
# 747  {'How': '1', 'a': '2', 'Play': '2', 'Google': ...
# 748  {'which': '2', 'the': '3', 'path': '1', 'this'...
# 749  {'arethe': '1', 'portnoy.': '1', 'fart': '1', ...
# 750  {'Pottermore:': '1', 'and': '1', 'wand': '1', ...
# 751  {'pulse': '1', 'e.m.p': '1', 'electromagnetic'...
# 752  {'shared': '1', 'Twitter': '1', 'Photograph': ...
# 753  {'a': '1', 'extension': '1', 'RainTPL': '1', '...
# 754  {'the': '2', 'repensando': '1', 'Uruguay': '1'...
# 755  {'the': '2', 'a': '1', 'researcher': '1', 'Mal...
# 756  {'Red': '1', 'the': '2', 'a': '2', 'abuse': '1...
# 757  {'Artur': '2', 'Romeu.': '2', 'Photo': '2', 'b...
# 758  {'Justice': '1', 'the': '3', 'having': '1', 'i...
# 759  {'the': '1', 'trading': '1', 'rus': '1', 'with...
# 760  {'English': '2', 'his': '1', 'Ukrainsk,': '1',...
# 761  {'news': '1', 'the': '2', 'SAbaseen': '1', 'of...
# 762  {'SICamp': '1', 'Barcamp': '2', 'kind': '1', '...
# 763  {'the': '2', 'a': '1', 'behind': '1', 'later':...
# 764  {'shares': '1', 'a': '1', 'She': '1', 'images'...
# 765  {'Beijing': '1', 'journalist': '1', 'Juste': '...
# 766  {'Women': '1', 'Delivers': '1', 'Saudi': '1', ...
# 767  {'Women': '2', 'Delivers': '1', 'Saudi': '2', ...
# 768  {'the': '1', 'New': '1', 'include': '1', 'citi...
# 769  {'Hassan.': '2', 'Shiraz': '2', 'Image': '2', ...
# 770  {'Malala': '1', '12': '1', 'Celebrate': '1', '...
# 771  {'which': '2', 'the': '3', 'path': '1', 'this'...
# 772                            {'slsm': '1', '.': '1'}
# 773  {'the': '1', 'to': '1', 'snootch': '1', 'mothe...
# 774     {'so?': '1', 'he?': '1', '-': '2', 'did': '1'}
# 775  {'better': '1', 'for': '1', 'a': '1', 'Syrian'...
# 776  {'stickito': '1', '.': '1', 'el': '1', 'squidi...
# 777  {'the': '1', 'pimbie': '1', 'steve': '1', 'bur...
# 778  {'The': '1', 'New': '1', 'ongoing': '1', 'mate...
# 779  {'the': '1', 'audience': '1', 'as': '1', 'TED'...
# 780  {'or': '1', 'yes': '1', 'Do': '1', 'support': ...
# 781                                     {'then?': '2'}
# 782  {'Malala': '1', '12': '1', 'Celebrate': '1', '...
# 783                        {'tomorrow': '1', '.': '1'}
# 784  {'believe': '1', 'to': '1', 'trying': '1', '.'...
# 785  {'fan': '2', 'b': '2', 'be': '2', 'would': '3'...
# 786  {'shared': '1', 'Photo': '1', '@CannabisMagazi...
# 787  {'doing': '1', 'what': '1', 'are': '1', 'ty': ...
# 788  {'Malala': '1', 'UN,': '1', 'Yousafzai': '1', ...
# 789                                   {'uh-huh!': '1'}
# 790  {'the': '1', 'computer': '1', 'at': '1', 'scie...
# 791  {'19:50': '1', 'at': '1', 'Updated': '1', 'GMT...
# 792  {'the': '1', 'visiting': '1', 'are': '1', 'and...
# 793  {'a': '1', 'some': '1', 'doing': '1', 'ways': ...
# 794  {'a': '2', 'Referring': '1', 'seventh': '1', '...
# 795  {'ever': '1', 'WIMPs': '1', 'be': '2', 'wave-p...
# 796  {'Dan': '1', 'Phra': '1', 'Tod,': '1', 'Kun': ...
# 797  {'which': '1', 'the': '1', 'in': '1', 'are': '...
# 798                          {'whoops': '1', '.': '1'}
# 799  {'the': '3', 'a': '1', 'Laura': '1', 'perfect'...
# 800  {'WordRidden': '1', '2.0)': '1', 'flickr': '1'...
# 801  {'the': '2', 'Can': '1', 'a': '2', 'Solutions'...
# 802     {',': '1', 'yo': '1', '.': '1', 'zoinks': '1'}
# 803  {'but': '1', 'a': '1', 'persecuted': '1', 'me'...
# 804  {'nor': '1', 'taste': '1', 'cool': '1', 'drink...
# 805  {'(cool)': '1', 'be': '1', 'associates': '1', ...
# 806  {'the': '3', 'Therein': '1', 'that': '2', 'not...
# 807  {'the': '2', 'brought': '1', 'in': '2', 'Holy'...
# 808  {'the': '9', 'as': '2', 'be': '2', 'His': '2',...
# 809  {'the': '2', 'in': '2', 'believe!': '1', 'amon...
# 810  {'and': '6', 'have': '5', 'for': '6', 'from': ...
# 811  {'but': '2', 'no': '1', 'such': '3', 'a': '4',...
# 812  {'that': '1', '(I': '1', 'part': '1', 'for': '...
# 813  {'the': '6', 'a': '3', 'with': '3', 'are': '3'...
# 814  {'the': '2', 'Lord': '2', 'not': '2', 'be': '2...
# 815  {'the': '16', 'with': '4', 'a': '5', 'in': '5'...
# 816  {'the': '8', 'that': '2', 'Night': '2', 'made'...
# 817  {'the': '10', 'that': '4', 'in': '4', 'will': ...
# 818  {'shower': '1', 'of)': '1', 'them,': '1', 'of'...
# 819  {'nor': '2', 'the': '3', 'made': '3', 'by': '2...
# 820  {'the': '2', 'which': '2', 'but': '4', 'that':...
# 821  {'the': '6', 'a': '4', 'some': '4', 'and': '4'...
# 822  {'that': '2', 'stayed': '3', 'and': '3', 'one'...
# 823  {'and': '2', 'one': '1', 'me': '1', 'my': '3',...
# 824  {'the': '1', 'dispute': '1', 'signs': '1', 'in...
# 825  {'the': '14', 'a': '5', 'and': '8', 'of': '6',...
# 826  {'but': '2', 'But': '2', 'the': '7', 'that': '...
# 827  {'call': '1', 'Lord': '2', 'thy': '1', 'Allah!...
# 828  {'the': '3', 'a': '3', 'in': '3', 'and': '5', ...
# 829  {'the': '6', 'what': '3', 'in': '5', 'of': '6'...
# 830  {'the': '1', 'that': '1', 'and': '2', 'Say:': ...
# 831  {'nor': '2', 'the': '3', 'in': '2', 'made': '3...
# 832  {'the': '2', 'became': '1', 'a': '2', 'been': ...
# 833  {'that': '1', 'think': '1', 'as': '1', ''And':...
# 834  {'all': '3', 'the': '19', 'that': '6', 'in': '...
# 835  {'the': '1', 'over': '2', 'His': '1', '(watchi...
# 836  {'can': '1', 'with': '2', 'thee': '2', 'afflic...
# 837  {'the': '6', 'can': '2', 'no': '2', 'His': '5'...
# 838  {'the': '2', 'plot': '1', 'before': '1', 'and'...
# 839  {'the': '9', 'a': '2', 'will': '6', 'of': '7',...
# 840  {'the': '5', 'Like': '1', 'Evil': '2', 'of': '...
# 841  {'remember': '1', 'what': '1', '(now),': '1', ...
# 842  {'That': '1', 'the': '2', 'rain': '1', '(from'...
# 843  {'but': '2', 'the': '2', 'and': '3', 'towns': ...
# 844  {'but': '1', 'the': '3', 'Not': '1', 'in': '1'...
# 845  {'a': '1', '(Qur'an)': '1', 'Message': '1', 'i...
# 846  {'behind': '1', 'what': '2', 'before': '1', 'a...
# 847  {'that': '2', 'not': '1', 'in': '2', 'believe!...
# 848  {'the': '2', 'When': '1', 'saved': '1', 'and':...
# 849  {'which': '2', 'matters': '2', 'are': '1', 'in...
# 850  {'therein,-': '1', 'burn': '1', 'Into': '1', '...
# 851  {'When': '1', 'turned': '1', 'upside': '1', 'i...
# 852  {'summer,-': '1', 'covenants': '1', 'journeys'...
# 853  {'but': '2', 'the': '11', 'not': '4', 'what': ...
# 854  {'the': '7', 'would': '3', 'will': '4', 'in': ...
# 855  {'unable': '1', 'a': '2', 'brought': '1', 'and...
# 856  {'the': '3', 'said,': '1', 'Lord': '2', 'and':...
# 857  {'with': '1', 'Thee': '1', '"And': '1', 'refug...
# 858  {'the': '4', 'Or': '1', 'in': '2', 'are': '2',...
# 859  {'the': '5', 'that': '2', 'a': '4', 'might': '...
# 860  {'the': '37', 'in': '9', 'will': '10', 'and': ...
# 861  {'the': '2', 'were': '2', 'was': '1', 'wont': ...
# 862  {'the': '1', 'not': '1', '(with': '1', 'Had': ...
# 863  {'the': '36', 'a': '27', 'in': '20', 'and': '1...
# 864  {'the': '30', 'that': '6', 'with': '8', 'in': ...
# 865  {'all': '1', 'The': '1', 'sounded,': '2', 'tha...
# 866  {'which': '4', 'the': '4', 'that': '5', 'been'...
# 867  {'the': '3', 'a': '3', 'that': '4', 'be': '2',...
# 868  {'abrogate': '1', 'or': '2', 'revelations': '1...
# 869  {'the': '4', 'that': '4', 'of': '2', 'incurred...
# 870  {'a': '2', 'admonish': '1', 'may': '2', 'in': ...
# 871  {'Nor': '1', 'the': '4', 'thee': '1', 'not': '...
# 872  {'the': '6', 'that': '3', 'in': '5', 'and': '6...
# 873  {'thee': '1', 'When': '1', 'in': '2', 'and': '...
# 874  {'the': '2', 'proved,': '1', 'be': '1', 'charg...
# 875  {'all': '2', 'the': '6', 'His': '3', 'and': '2...
# 876  {'nor': '1', 'No': '1', 'can': '2', 'term,': '...
# 877  {'forsake': '1', 'the': '2', 'limbs': '1', 'an...
# 878  {'a': '1', 'planning': '1', 'I': '1', 'scheme....
# 879  {'feet': '1', 'no': '2', 'hands': '1', 'Or': '...
# 880  {'remember': '1', 'the': '2', 'a': '2', 'as': ...
# 881  {'all': '2', 'the': '3', 'will': '3', 'of': '3...
# 882  {'that': '1', 'take': '1', 'alms,': '1', 'good...
# 883  {'the': '4', 'Thy': '2', 'and': '4', 'of': '2'...
# 884  {'the': '3', 'with': '2', 'and': '4', 'for': '...
# 885  {'the': '6', 'that': '3', 'in': '4', 'of': '5'...
# 886  {'the': '6', 'not': '3', 'will': '2', 'were': ...
# 887  {'the': '2', 'Remember!': '1', 'and': '2', 'of...
# 888  {'the': '8', 'a': '3', 'not': '3', 'or': '3', ...
# 889  {'the': '62', 'that': '22', 'a': '31', 'will':...
# 890  {'a': '2', 'When': '1', '(first)': '1', 'messe...
# 891  {'these': '1', 'the': '2', 'a': '2', 'cult': '...
# 892  {'the': '6', 'them,': '2', 'of': '3', 'Ask': '...
# 893  {'the': '2', 'no': '2', 'there': '2', 'one': '...
# 894  {'Charity,': '1', 'give': '1', 'a': '2', 'in':...
# 895  {'square': '1', 'firm': '1', 'that': '1', 'may...
# 896  {'the': '2', 'concerning': '1', 'thee': '2', '...
# 897  {'the': '3', 'that': '2', 'will': '4', 'and': ...
# 898  {'which': '1', 'given': '1', 'How': '1', 'dest...
# 899  {'righteousness,': '1', 'As': '1', 'verily': '...
# 900  {'That': '1', 'a': '1', 'that': '1', 'Faith;':...
# 901  {'the': '2', 'not': '1', 'squat': '1', '"And':...
# 902  {'that': '1', 'see': '1', 'not': '1', 'created...
# 903  {'nor': '1', 'the': '2', 'Not': '1', 'will': '...
# 904  {'the': '3', 'Lord': '1', 'in': '2', 'and': '4...
# 905  {'(Allah)': '1', 'said:': '1', '(way': '1', 's...
# 906  {'which': '2', 'that': '1', 'will': '2', 'have...
# 907  {'the': '7', 'a': '3', 'that': '4', 'not': '6'...
# 908  {'the': '3', 'that': '1', '(straight):': '1', ...
# 909  {'the': '6', 'that': '4', 'see': '1', 'face': ...
# 910  {'The': '1', 'reject': '1', 'and': '2', 'of': ...
# 911  {'admit': '1', 'righteous': '1', 'will': '3', ...
# 912  {'the': '1', 'with': '1', 'in': '1', 'marriage...
# 913  {'Lord': '1', 'thy': '1', 'And': '1', 'Most': ...
# 914  {'the': '7', 'and': '10', 'of': '6', 'for': '3...
# 915  {'the': '3', 'in': '2', 'celebrate': '2', 'of'...
# 916  {'the': '4', 'will': '5', 'and': '5', 'by': '3...
# 917  {'a': '5', 'not': '2', 'are': '2', 'in': '4', ...
# 918  {'the': '162', 'a': '36', 'in': '54', 'and': '...
# 919  {'That': '1', 'into': '2', 'and': '3', 'night'...
# 920  {'the': '2', 'not': '2', '(to': '4', 'Messenge...
# 921  {'the': '2', 'all': '2', 'that': '2', 'a': '2'...
# 922  {'Abraham': '2', 'the': '3', 'with': '2', 'Fai...
# 923  {'the': '1', '[/math]?': '1', 'of': '1', 'is':...
# 924                                    {'voila.': '1'}
# 925  {'the': '1', 'flip.': '1', 'yeah,': '1', 'on':...
# 926                    {'[claire]': '1', 'blah!': '1'}
# 927                                       {'hm?': '1'}
# 928  {'with': '1', 'not': '1', 'you?': '1', 'jong?'...
# 929  {'worse?': '1', 'he'll': '1', 'becoming': '1',...
# 930              {'estoy': '1', '.': '1', 'bien': '1'}
# 931  {'these': '1', '360s': '1', 'hundred': '1', 'f...
# 932  {'the': '1', 'with': '1', 'woman': '1', 'creek...
# 933  {'http://t.co/aX2o5V2D5R': '1', 'what': '1', '...
# 934                           {'July': '1', '21': '1'}
# 935                 {'Creative': '1', 'commons.': '1'}
# 936  {'see': '3', 'be': '9', 'blue': '2', 'hurtful'...
# 937  {'the': '2', 'a': '1', '"Through': '1', 'and':...
# 938  {'which': '1', 'the': '1', 'can': '1', 'glenfi...
# 939  {'of': '1', 'i': '2', 'is': '1', 'it': '1', 'n...
# 940  {'Suivez': '1', 'de': '3', 'ce': '1', 'Barlet'...
# 941  {'a': '1', 'covering': '1', 'CNNTurk': '1', 'o...
# 942  {'yi': '1', 'not': '1', 'even': '1', 'and': '1...
# 943  {'the': '1', 'de': '3', 'site': '1', 'ce': '2'...
# 944  {'like': '1', 'find': '1', 'might': '1', 'me':...
# 945  {'his': '1', 'hes': '1', 'i': '2', 'blockers':...
# 946  {'the': '4', 'bus': '1', 'a': '4', 'wake': '1'...
# 947  {'us.': '1', 'bu': '1', 'yeosun': '1', 'like':...
# 948  {'bromfenbrenner': '1', 'bring': '1', 'doc': '...
# 949  {'not': '1', 'me': '1', 'i': '1', 'lonely': '1...
# 950  {'the': '2', 'said:': '1', 'Like': '1', 'Tehra...
# 951  {'hungry': '1', 'im': '1', 'kind': '1', 'of': ...
# 952  {'the': '1', 'with': '1', 'woman': '1', 'creek...
# 953  {'the': '5', 'wait': '2', '3': '2', 'Should': ...
# 954  {'that': '1', 'a': '2', 'and': '2', 'of': '2',...
# 955  {'centuries,': '1', 'were': '1', 'forbidden': ...
# 956                 {',': '9', 'lies': '14', '.': '5'}
# 957  {'Flickr': '1', '2014': '1', 'by': '1', 'taken...
# 958  {'further.': '1', 'aggravated': '1', 'have': '...
# 959  {'your': '1', 'mind?': '1', 'were': '1', 'you'...
# 960                           {'moshi': '2', '.': '1'}
# 961  {'2.0)': '1', 'flickr': '1', 'BY': '1', 'by': ...
# 962  {'Suivez': '1', 'de': '3', 'ce': '1', 'Barlet'...
# 963  {'the': '1', 'score': '1', 'with': '1', 'a': '...
# 964  {'but': '1', 'private': '1', 'don't': '1', 'af...
# 965  {'UGC': '1', 'the': '1', 'prepare': '1', 'How'...
# 966  {'nocte': '1', 'consumimur': '1', 'imus': '1',...
# 967  {'which': '1', 'samson': '1', 'and': '1', 'c03...
# 968  {'some': '1', 'discovered': '1', 'at': '1', 'I...
# 969  {'find': '1', 'them': '1', 'must': '1', 'your'...
# 970  {'the': '1', 'The': '1', '(#citizenj)': '1', '...
# 971  {'with': '1', 'your': '1', 'in': '1', 'eyes': ...
# 972  {'the': '1', 'a': '2', 'Javascript?': '1', 'in...
# 973  {'the': '1', 'feel': '1', 'rhythm': '1', ',': ...
# 974  {'right.': '2', 'seeing': '1', 'should': '1', ...
# 975  {'six.': '1', 'five,': '2', 'seven,': '1', 'ei...
# 976  {'some': '2', 'stop': '1', 'will': '1', 'could...
# 977  {'but': '1', 'found': '1', 'now': '1', 'ill': ...
# 978  {'next': '1', 'door': '1', 'a': '1', 'still': ...
# 979  {'the': '3', 'of': '1', 'municipal': '1', 'Bra...
# 980  {'tub': '1', 'the': '1', 'bitch': '1', 'in': '...
# 981  {'the': '1', 'best': '1', 'two': '1', '.': '1'...
# 982  {'lm': '1', 'sorry': '1', 'oh': '1', 'so': '1'...
# 983  {'none': '1', '.': '1', 'did': '1', 'us': '1',...
# 984  {'the': '1', 'that': '1', 'like': '1', 'didn't...
# 985  {'sky': '1', 'violet': '1', 'i': '1', 'be': '1...
# 986                        {'wide!': '1', 'open': '1'}
# 987  {'the': '1', 'these': '1', 'people': '1', 'pos...
# 988  {'hey,': '2', 'going': '1', 'didn't': '1', 'yo...
# 989  {'love': '1', 'with': '1', 'Eliza,': '1', 'be'...
# 990  {'darkopal': '4', 'subtitles': '4', 'bolt': '4...
# 991  {'the': '1', 'a': '1', 'winning': '1', 'going'...
# 992  {'a': '2', 'Jaafari': '1', 'and': '2', 'by': '...
# 993  {'these': '2', 'a': '1', 'take': '1', 'think':...
# 994  {'a': '1', 'government': '1', 'in': '1', 'In':...
# 995  {'harrassment"': '1', 'such': '1', 'as': '1', ...
# 996  {'the': '4', 'how': '2', 'me,': '2', 'in': '2'...
# 997  {'a': '1', 'feast,': '1', 'made': '1', 'And': ...
# 998  {'george': '1', 'company': '2', ',': '1', 'and...
# 999  {'the': '3', 'A': '1', 'a': '3', 'protestor': ...
